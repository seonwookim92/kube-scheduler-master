# %% [markdown]
# # Data Generation

# %% [markdown]
# ## 1. 1-label data generation

# %%
# Load gym environment
import gym
from kube_sim_gym import *
from kube_sim_gym.envs.sim_kube_env import SimKubeEnv

# %%
from kube_hr_scheduler.scheduler.sim_hr_scheduler import SimHrScheduler
from kube_hr_scheduler.strategies.model.default import Model

# %%
env = gym.make('SimKubeEnv-v0')
scheduler = SimHrScheduler(env, 'default.py')

# %%
# Data generation
# Data consists of state, scheduler decision
data_size = 10000000
with open('data.csv', 'w') as f:
    for i in range(data_size):
        state = list(env.random_state_gen())
        action = scheduler.decision(env)
        data = state + [action]
        f.write(','.join(list(map(str,data))) + '\n')

# %% [markdown]
# ## 2. 6-confidence data generation

# %%
# Load gym environment
import gym
from kube_sim_gym import *
from kube_sim_gym.envs.sim_kube_env import SimKubeEnv

# %%
from kube_hr_scheduler.scheduler.sim_hr_scheduler import SimHrScheduler
from kube_hr_scheduler.strategies.model.default import Model

# %%
env = gym.make('SimKubeEnv-v0')
scheduler = SimHrScheduler(env, 'default.py')

# %%
# Data generation
# Data consists of state, scheduler decision
data_size = 1000000
with open('data_2.csv', 'w') as f:
    for i in range(data_size):
        state = list(env.random_state_gen())
        confidence = scheduler.get_confidence(env)
        data = state + confidence.tolist()
        f.write(','.join(list(map(str,data))) + '\n')

# %% [markdown]
# # Training

# %% [markdown]
# ## Set Dataset

# %%
import torch
from torch.utils.data import Dataset, DataLoader

import pandas as pd

# %%
class CustomDataset(Dataset):
    def __init__(self, csv_path, train=True):
        self.data = pd.read_csv(csv_path)

        if train:
            self.data = self.data.sample(frac=0.8, random_state=42)
        else:
            self.data = self.data.drop(self.data.sample(frac=0.8, random_state=42).index)

        self.data = self.transform(self.data)
        self.input = self.data[:, :-1]
        self.label = self.data[:, -1]
        # Long tensor for cross entropy loss
        self.label = torch.tensor(self.label, dtype=torch.long)

    def transform(self, data):
        return torch.tensor(data.values, dtype=torch.float32)

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.input[idx], self.label[idx]

# %%
train_dataset = CustomDataset('data.csv', train=True)
test_dataset = CustomDataset('data.csv', train=False)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# /var/folders/gl/n3l9mrsx1jz4xhb0rsxhj8980000gn/T/ipykernel_3520/1400017947.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.label = torch.tensor(self.label, dtype=torch.long)
# /var/folders/gl/n3l9mrsx1jz4xhb0rsxhj8980000gn/T/ipykernel_3520/1400017947.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.label = torch.tensor(self.label, dtype=torch.long)

# %%
for batch in train_dataloader:
    inputs, labels = batch
    print(inputs.shape, labels.shape)
    print(inputs, labels)
    break
# Out:
# torch.Size([32, 12]) torch.Size([32])
# tensor([[0.4800, 0.1100, 0.1000, 0.5700, 0.8100, 0.2800, 0.1800, 0.9800, 0.6300,
#          0.1300, 0.0000, 0.0000],
#         [0.3400, 1.0000, 0.3200, 0.6500, 0.4300, 0.7700, 0.7200, 0.2400, 0.8400,
#          0.1700, 0.0000, 0.0000],
#         [0.8800, 0.7000, 0.6600, 0.1100, 0.4900, 0.2900, 0.6500, 0.5100, 0.4300,
#          0.5300, 0.4000, 0.0300],
#         [0.1600, 0.0000, 0.7000, 0.6500, 0.6400, 0.9700, 0.1800, 0.0400, 0.7300,
#          0.0100, 0.2900, 0.4400],
#         [0.8700, 0.3700, 0.4800, 0.3700, 0.0400, 0.0800, 0.1500, 0.3000, 0.1300,
#          0.1500, 0.0000, 0.0000],
#         [0.9700, 0.0200, 0.5200, 0.8900, 0.1300, 0.8300, 0.0600, 0.1200, 0.0900,
#          0.3600, 0.0000, 0.0000],
#         [0.2300, 0.0200, 0.0700, 0.4400, 0.2300, 0.4700, 0.7700, 0.6900, 0.6000,
#          0.3600, 0.0200, 0.1600],
#         [0.6900, 0.5900, 0.4700, 0.6900, 0.5300, 0.8000, 0.1300, 0.3900, 0.3700,
#          0.7600, 0.0400, 0.1400],
#         [0.8000, 0.2500, 0.4200, 0.2300, 0.6300, 0.5800, 0.3200, 0.1800, 0.9700,
#          0.5100, 0.2600, 0.0500],
#         [0.8100, 0.8100, 0.4200, 0.5900, 0.5600, 0.7400, 0.8600, 0.4900, 0.9300,
#          0.5600, 0.0000, 0.0000],
#         [0.4900, 0.3200, 0.5100, 0.1900, 0.4700, 0.6200, 0.1200, 0.1500, 0.0600,
#          0.1000, 0.4000, 0.1500],
#         [0.5500, 0.1300, 0.8000, 0.2000, 0.0700, 0.8500, 0.7900, 0.2800, 0.2200,
#          0.0900, 0.3100, 0.3600],
#         [0.9300, 0.7800, 0.1600, 0.0300, 0.4900, 0.2000, 0.6100, 0.0400, 0.8000,
#          0.0800, 0.0000, 0.0000],
#         [0.0500, 0.2000, 0.9900, 0.8600, 0.5900, 0.1800, 0.7100, 0.4300, 0.1300,
#          0.9300, 0.3300, 0.0000],
#         [0.1400, 0.3900, 0.7100, 0.5100, 0.7400, 0.9500, 0.7300, 0.1700, 0.5900,
#          0.8100, 0.0000, 0.0000],
#         [0.5200, 0.4600, 0.1600, 0.5500, 0.1500, 0.6900, 0.2300, 0.3700, 0.6100,
#          0.6400, 0.2500, 0.3200],
#         [0.1900, 0.7200, 0.6400, 0.4700, 0.6900, 0.8900, 0.3300, 0.6600, 0.6400,
#          0.7600, 0.4400, 0.4400],
#         [0.0100, 0.8500, 0.2000, 0.3300, 0.5500, 0.3800, 0.3600, 0.0100, 0.7800,
#          0.9000, 0.4700, 0.3800],
#         [0.3000, 0.1600, 0.1600, 0.1700, 0.6500, 0.3700, 0.3800, 0.4500, 0.4400,
#          0.3500, 0.0000, 0.0100],
#         [0.7200, 0.0500, 0.5700, 0.5600, 0.9600, 0.2000, 0.5200, 0.1000, 0.9600,
#          0.1200, 0.2200, 0.0300],
#         [0.9800, 0.7700, 0.9600, 0.0500, 0.4700, 0.7400, 0.1000, 0.4000, 0.7100,
#          0.9300, 0.2200, 0.2000],
#         [0.5900, 0.8500, 0.2100, 0.9900, 0.5400, 0.7400, 0.3800, 0.1200, 0.8600,
#          0.5400, 0.2200, 0.0300],
#         [0.3900, 0.0100, 0.6700, 0.6100, 0.7100, 0.2100, 0.3900, 0.5700, 0.0100,
#          0.4200, 0.0400, 0.0400],
#         [0.0600, 0.2000, 0.0100, 0.0900, 0.6700, 0.3700, 0.5800, 0.4100, 0.1500,
#          0.1900, 0.0700, 0.4700],
#         [0.7100, 0.1200, 0.4800, 0.2800, 0.8700, 0.4500, 0.1000, 0.3100, 0.1600,
#          0.2900, 0.0600, 0.1100],
#         [0.6700, 0.5000, 0.2400, 0.0500, 0.3700, 0.5800, 0.2700, 0.5200, 0.6900,
#          0.6400, 0.1500, 0.2100],
#         [0.0600, 0.0800, 0.8400, 0.7900, 0.7600, 0.9500, 0.4000, 0.6400, 0.8800,
#          0.2200, 0.0200, 0.2000],
#         [0.6300, 0.7300, 0.2100, 0.1300, 0.8500, 0.0200, 0.3300, 0.8600, 0.4700,
#          0.1400, 0.3500, 0.0500],
#         [0.4700, 0.4200, 0.2100, 0.5500, 0.9500, 0.5200, 0.8800, 0.4400, 0.7300,
#          0.7000, 0.0200, 0.0400],
#         [0.9100, 0.4900, 0.3100, 0.0200, 0.4900, 0.1100, 0.8700, 0.7100, 0.7400,
#          0.9300, 0.2800, 0.5000],
#         [0.3700, 0.6100, 0.3800, 0.2500, 0.8300, 0.0000, 0.3900, 0.2100, 0.8900,
#          0.9600, 0.2800, 0.2900],
#         [0.5300, 0.4700, 0.2100, 0.2600, 0.4600, 0.8300, 0.3300, 0.9000, 0.6800,
#          0.3000, 0.2500, 0.0200]]) tensor([0, 0, 5, 1, 0, 0, 1, 4, 4, 0, 5, 5, 0, 1, 0, 4, 0, 2, 2, 2, 4, 4, 1, 2,
#         5, 2, 1, 2, 1, 2, 2, 2])

# %% [markdown]
# ## Model

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(12, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 6)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
net = Net()
print(net)
# Out:
# Net(
#   (fc1): Linear(in_features=12, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=6, bias=True)
# )

# %%
# Training
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# ## Train

# %%
def train(model, train_loader, criterion, optimizer):
    model.train()
    train_loss = 0
    correct = 0
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        # print(f"output: {output}")
        # print(f"target: {target}")
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data.size(0)
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
    train_loss /= len(train_loader.dataset)
    accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss, accuracy

# %%
def test(model, test_loader, criterion):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            test_loss += criterion(output, target).item() * data.size(0)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, accuracy

# %%
epochs = 500
test_acc = 0
for epoch in range(1, epochs+1):
    train_loss, train_acc = train(net, train_dataloader, criterion, optimizer)
    test_loss, test_acc = test(net, test_dataloader, criterion)
    print(f'Epoch {epoch}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
    if test_acc > 99:
        break
# Out:
# Epoch 1: Train Loss: 0.8049, Train Acc: 71.55%, Test Loss: 0.5964, Test Acc: 77.76%
# Epoch 2: Train Loss: 0.4581, Train Acc: 82.60%, Test Loss: 0.3409, Test Acc: 86.98%
# Epoch 3: Train Loss: 0.2698, Train Acc: 90.05%, Test Loss: 0.2561, Test Acc: 90.45%
# Epoch 4: Train Loss: 0.2352, Train Acc: 91.35%, Test Loss: 0.2483, Test Acc: 90.86%
# Epoch 5: Train Loss: 0.2266, Train Acc: 91.75%, Test Loss: 0.2422, Test Acc: 91.11%
# Epoch 6: Train Loss: 0.2218, Train Acc: 91.94%, Test Loss: 0.2398, Test Acc: 91.25%
# Epoch 7: Train Loss: 0.2182, Train Acc: 92.11%, Test Loss: 0.2371, Test Acc: 91.40%
# Epoch 8: Train Loss: 0.2151, Train Acc: 92.26%, Test Loss: 0.2356, Test Acc: 91.47%
# Epoch 9: Train Loss: 0.2120, Train Acc: 92.38%, Test Loss: 0.2307, Test Acc: 91.53%
# Epoch 10: Train Loss: 0.2093, Train Acc: 92.47%, Test Loss: 0.2266, Test Acc: 91.70%
# Epoch 11: Train Loss: 0.2065, Train Acc: 92.56%, Test Loss: 0.2216, Test Acc: 91.79%
# Epoch 12: Train Loss: 0.2037, Train Acc: 92.66%, Test Loss: 0.2182, Test Acc: 91.88%
# Epoch 13: Train Loss: 0.2008, Train Acc: 92.71%, Test Loss: 0.2148, Test Acc: 92.06%
# Epoch 14: Train Loss: 0.1981, Train Acc: 92.79%, Test Loss: 0.2120, Test Acc: 92.11%
# Epoch 15: Train Loss: 0.1950, Train Acc: 92.88%, Test Loss: 0.2087, Test Acc: 92.25%
# Epoch 16: Train Loss: 0.1918, Train Acc: 93.01%, Test Loss: 0.2052, Test Acc: 92.42%
# Epoch 17: Train Loss: 0.1882, Train Acc: 93.10%, Test Loss: 0.2011, Test Acc: 92.50%
# Epoch 18: Train Loss: 0.1844, Train Acc: 93.24%, Test Loss: 0.1966, Test Acc: 92.75%
# Epoch 19: Train Loss: 0.1810, Train Acc: 93.36%, Test Loss: 0.1932, Test Acc: 92.92%
# Epoch 20: Train Loss: 0.1776, Train Acc: 93.45%, Test Loss: 0.1913, Test Acc: 92.99%
# Epoch 21: Train Loss: 0.1741, Train Acc: 93.54%, Test Loss: 0.1874, Test Acc: 93.18%
# Epoch 22: Train Loss: 0.1707, Train Acc: 93.64%, Test Loss: 0.1869, Test Acc: 93.14%
# Epoch 23: Train Loss: 0.1673, Train Acc: 93.75%, Test Loss: 0.1839, Test Acc: 93.30%
# Epoch 24: Train Loss: 0.1637, Train Acc: 93.86%, Test Loss: 0.1795, Test Acc: 93.42%
# Epoch 25: Train Loss: 0.1600, Train Acc: 93.95%, Test Loss: 0.1772, Test Acc: 93.47%
# Epoch 26: Train Loss: 0.1564, Train Acc: 94.07%, Test Loss: 0.1730, Test Acc: 93.56%
# Epoch 27: Train Loss: 0.1530, Train Acc: 94.19%, Test Loss: 0.1701, Test Acc: 93.66%
# Epoch 28: Train Loss: 0.1496, Train Acc: 94.30%, Test Loss: 0.1658, Test Acc: 93.84%
# Epoch 29: Train Loss: 0.1466, Train Acc: 94.40%, Test Loss: 0.1636, Test Acc: 93.90%
# Epoch 30: Train Loss: 0.1435, Train Acc: 94.49%, Test Loss: 0.1589, Test Acc: 93.96%
# Epoch 31: Train Loss: 0.1404, Train Acc: 94.58%, Test Loss: 0.1546, Test Acc: 94.06%
# Epoch 32: Train Loss: 0.1371, Train Acc: 94.66%, Test Loss: 0.1538, Test Acc: 94.21%
# Epoch 33: Train Loss: 0.1349, Train Acc: 94.76%, Test Loss: 0.1524, Test Acc: 94.05%
# Epoch 34: Train Loss: 0.1318, Train Acc: 94.87%, Test Loss: 0.1487, Test Acc: 94.24%
# Epoch 35: Train Loss: 0.1297, Train Acc: 94.93%, Test Loss: 0.1468, Test Acc: 94.34%
# Epoch 36: Train Loss: 0.1269, Train Acc: 95.05%, Test Loss: 0.1461, Test Acc: 94.38%
# Epoch 37: Train Loss: 0.1250, Train Acc: 95.11%, Test Loss: 0.1439, Test Acc: 94.44%
# Epoch 38: Train Loss: 0.1230, Train Acc: 95.17%, Test Loss: 0.1435, Test Acc: 94.46%
# Epoch 39: Train Loss: 0.1210, Train Acc: 95.23%, Test Loss: 0.1403, Test Acc: 94.58%
# Epoch 40: Train Loss: 0.1191, Train Acc: 95.28%, Test Loss: 0.1430, Test Acc: 94.64%
# Epoch 41: Train Loss: 0.1175, Train Acc: 95.36%, Test Loss: 0.1408, Test Acc: 94.51%
# Epoch 42: Train Loss: 0.1157, Train Acc: 95.40%, Test Loss: 0.1393, Test Acc: 94.56%
# Epoch 43: Train Loss: 0.1144, Train Acc: 95.47%, Test Loss: 0.1357, Test Acc: 94.85%
# Epoch 44: Train Loss: 0.1128, Train Acc: 95.52%, Test Loss: 0.1373, Test Acc: 94.75%
# Epoch 45: Train Loss: 0.1115, Train Acc: 95.54%, Test Loss: 0.1371, Test Acc: 94.71%
# Epoch 46: Train Loss: 0.1100, Train Acc: 95.63%, Test Loss: 0.1334, Test Acc: 94.99%
# Epoch 47: Train Loss: 0.1091, Train Acc: 95.68%, Test Loss: 0.1346, Test Acc: 94.84%
# Epoch 48: Train Loss: 0.1072, Train Acc: 95.75%, Test Loss: 0.1343, Test Acc: 94.91%
# Epoch 49: Train Loss: 0.1068, Train Acc: 95.79%, Test Loss: 0.1461, Test Acc: 94.47%
# Epoch 50: Train Loss: 0.1049, Train Acc: 95.83%, Test Loss: 0.1373, Test Acc: 94.80%
# Epoch 51: Train Loss: 0.1042, Train Acc: 95.84%, Test Loss: 0.1381, Test Acc: 94.79%
# Epoch 52: Train Loss: 0.1028, Train Acc: 95.85%, Test Loss: 0.1388, Test Acc: 94.71%
# Epoch 53: Train Loss: 0.1019, Train Acc: 95.91%, Test Loss: 0.1415, Test Acc: 94.62%
# Epoch 54: Train Loss: 0.1008, Train Acc: 95.92%, Test Loss: 0.1421, Test Acc: 94.61%
# Epoch 55: Train Loss: 0.1002, Train Acc: 95.97%, Test Loss: 0.1399, Test Acc: 94.78%
# Epoch 56: Train Loss: 0.0989, Train Acc: 96.04%, Test Loss: 0.1375, Test Acc: 94.81%
# Epoch 57: Train Loss: 0.0983, Train Acc: 96.07%, Test Loss: 0.1389, Test Acc: 94.82%
# Epoch 58: Train Loss: 0.0973, Train Acc: 96.11%, Test Loss: 0.1365, Test Acc: 94.95%
# Epoch 59: Train Loss: 0.0965, Train Acc: 96.14%, Test Loss: 0.1362, Test Acc: 94.78%
# Epoch 60: Train Loss: 0.0951, Train Acc: 96.19%, Test Loss: 0.1334, Test Acc: 95.05%
# Epoch 61: Train Loss: 0.0949, Train Acc: 96.21%, Test Loss: 0.1320, Test Acc: 95.07%
# Epoch 62: Train Loss: 0.0941, Train Acc: 96.27%, Test Loss: 0.1326, Test Acc: 95.04%
# Epoch 63: Train Loss: 0.0934, Train Acc: 96.31%, Test Loss: 0.1307, Test Acc: 95.08%
# Epoch 64: Train Loss: 0.0925, Train Acc: 96.34%, Test Loss: 0.1330, Test Acc: 95.09%
# Epoch 65: Train Loss: 0.0918, Train Acc: 96.34%, Test Loss: 0.1363, Test Acc: 95.06%
# Epoch 66: Train Loss: 0.0909, Train Acc: 96.38%, Test Loss: 0.1331, Test Acc: 95.05%
# Epoch 67: Train Loss: 0.0907, Train Acc: 96.38%, Test Loss: 0.1311, Test Acc: 95.25%
# Epoch 68: Train Loss: 0.0901, Train Acc: 96.45%, Test Loss: 0.1324, Test Acc: 95.16%
# Epoch 69: Train Loss: 0.0890, Train Acc: 96.47%, Test Loss: 0.1320, Test Acc: 95.23%
# Epoch 70: Train Loss: 0.0889, Train Acc: 96.44%, Test Loss: 0.1298, Test Acc: 95.32%
# Epoch 71: Train Loss: 0.0881, Train Acc: 96.50%, Test Loss: 0.1337, Test Acc: 95.16%
# Epoch 72: Train Loss: 0.0874, Train Acc: 96.54%, Test Loss: 0.1324, Test Acc: 95.19%
# Epoch 73: Train Loss: 0.0873, Train Acc: 96.53%, Test Loss: 0.1308, Test Acc: 95.23%
# Epoch 74: Train Loss: 0.0866, Train Acc: 96.56%, Test Loss: 0.1300, Test Acc: 95.32%
# Epoch 75: Train Loss: 0.0865, Train Acc: 96.57%, Test Loss: 0.1319, Test Acc: 95.20%
# Epoch 76: Train Loss: 0.0857, Train Acc: 96.58%, Test Loss: 0.1320, Test Acc: 95.29%
# Epoch 77: Train Loss: 0.0846, Train Acc: 96.63%, Test Loss: 0.1294, Test Acc: 95.32%
# Epoch 78: Train Loss: 0.0850, Train Acc: 96.62%, Test Loss: 0.1302, Test Acc: 95.37%
# Epoch 79: Train Loss: 0.0842, Train Acc: 96.67%, Test Loss: 0.1287, Test Acc: 95.34%
# Epoch 80: Train Loss: 0.0835, Train Acc: 96.67%, Test Loss: 0.1253, Test Acc: 95.48%
# Epoch 81: Train Loss: 0.0831, Train Acc: 96.68%, Test Loss: 0.1254, Test Acc: 95.53%
# Epoch 82: Train Loss: 0.0830, Train Acc: 96.69%, Test Loss: 0.1256, Test Acc: 95.50%
# Epoch 83: Train Loss: 0.0821, Train Acc: 96.74%, Test Loss: 0.1238, Test Acc: 95.59%
# Epoch 84: Train Loss: 0.0817, Train Acc: 96.76%, Test Loss: 0.1232, Test Acc: 95.59%
# Epoch 85: Train Loss: 0.0822, Train Acc: 96.75%, Test Loss: 0.1197, Test Acc: 95.60%
# Epoch 86: Train Loss: 0.0812, Train Acc: 96.76%, Test Loss: 0.1228, Test Acc: 95.62%
# Epoch 87: Train Loss: 0.0806, Train Acc: 96.80%, Test Loss: 0.1228, Test Acc: 95.63%
# Epoch 88: Train Loss: 0.0804, Train Acc: 96.80%, Test Loss: 0.1194, Test Acc: 95.75%
# Epoch 89: Train Loss: 0.0804, Train Acc: 96.81%, Test Loss: 0.1238, Test Acc: 95.62%
# Epoch 90: Train Loss: 0.0807, Train Acc: 96.81%, Test Loss: 0.1194, Test Acc: 95.78%
# Epoch 91: Train Loss: 0.0794, Train Acc: 96.84%, Test Loss: 0.1235, Test Acc: 95.66%
# Epoch 92: Train Loss: 0.0796, Train Acc: 96.84%, Test Loss: 0.1215, Test Acc: 95.72%
# Epoch 93: Train Loss: 0.0792, Train Acc: 96.83%, Test Loss: 0.1207, Test Acc: 95.76%
# Epoch 94: Train Loss: 0.0785, Train Acc: 96.87%, Test Loss: 0.1221, Test Acc: 95.76%
# Epoch 95: Train Loss: 0.0782, Train Acc: 96.86%, Test Loss: 0.1258, Test Acc: 95.62%
# Epoch 96: Train Loss: 0.0782, Train Acc: 96.89%, Test Loss: 0.1240, Test Acc: 95.68%
# Epoch 97: Train Loss: 0.0778, Train Acc: 96.89%, Test Loss: 0.1235, Test Acc: 95.71%
# Epoch 98: Train Loss: 0.0771, Train Acc: 96.90%, Test Loss: 0.1231, Test Acc: 95.72%
# Epoch 99: Train Loss: 0.0785, Train Acc: 96.88%, Test Loss: 0.1269, Test Acc: 95.54%
# Epoch 100: Train Loss: 0.0770, Train Acc: 96.95%, Test Loss: 0.1216, Test Acc: 95.78%
# Epoch 101: Train Loss: 0.0769, Train Acc: 96.92%, Test Loss: 0.1261, Test Acc: 95.70%
# Epoch 102: Train Loss: 0.0764, Train Acc: 96.97%, Test Loss: 0.1262, Test Acc: 95.66%
# Epoch 103: Train Loss: 0.0762, Train Acc: 96.97%, Test Loss: 0.1241, Test Acc: 95.74%
# Epoch 104: Train Loss: 0.0758, Train Acc: 96.98%, Test Loss: 0.1248, Test Acc: 95.76%
# Epoch 105: Train Loss: 0.0754, Train Acc: 97.00%, Test Loss: 0.1288, Test Acc: 95.68%
# Epoch 106: Train Loss: 0.0755, Train Acc: 97.00%, Test Loss: 0.1201, Test Acc: 95.83%
# Epoch 107: Train Loss: 0.0755, Train Acc: 97.01%, Test Loss: 0.1240, Test Acc: 95.72%
# Epoch 108: Train Loss: 0.0751, Train Acc: 97.00%, Test Loss: 0.1207, Test Acc: 95.92%
# Epoch 109: Train Loss: 0.0748, Train Acc: 97.02%, Test Loss: 0.1252, Test Acc: 95.77%
# Epoch 110: Train Loss: 0.0742, Train Acc: 97.02%, Test Loss: 0.1230, Test Acc: 95.75%
# Epoch 111: Train Loss: 0.0739, Train Acc: 97.06%, Test Loss: 0.1206, Test Acc: 95.90%
# Epoch 112: Train Loss: 0.0749, Train Acc: 97.01%, Test Loss: 0.1231, Test Acc: 95.84%
# Epoch 113: Train Loss: 0.0736, Train Acc: 97.06%, Test Loss: 0.1224, Test Acc: 95.86%
# Epoch 114: Train Loss: 0.0743, Train Acc: 97.04%, Test Loss: 0.1171, Test Acc: 95.95%
# Epoch 115: Train Loss: 0.0734, Train Acc: 97.08%, Test Loss: 0.1225, Test Acc: 95.86%
# Epoch 116: Train Loss: 0.0731, Train Acc: 97.09%, Test Loss: 0.1256, Test Acc: 95.59%
# Epoch 117: Train Loss: 0.0728, Train Acc: 97.11%, Test Loss: 0.1250, Test Acc: 95.81%
# Epoch 118: Train Loss: 0.0723, Train Acc: 97.15%, Test Loss: 0.1231, Test Acc: 95.76%
# Epoch 119: Train Loss: 0.0725, Train Acc: 97.14%, Test Loss: 0.1259, Test Acc: 95.64%
# Epoch 120: Train Loss: 0.0714, Train Acc: 97.17%, Test Loss: 0.1221, Test Acc: 95.86%
# Epoch 121: Train Loss: 0.0718, Train Acc: 97.17%, Test Loss: 0.1234, Test Acc: 95.80%
# Epoch 122: Train Loss: 0.0716, Train Acc: 97.17%, Test Loss: 0.1207, Test Acc: 95.82%
# Epoch 123: Train Loss: 0.0707, Train Acc: 97.19%, Test Loss: 0.1186, Test Acc: 95.88%
# Epoch 124: Train Loss: 0.0710, Train Acc: 97.20%, Test Loss: 0.1199, Test Acc: 95.86%
# Epoch 125: Train Loss: 0.0709, Train Acc: 97.20%, Test Loss: 0.1187, Test Acc: 95.86%
# Epoch 126: Train Loss: 0.0708, Train Acc: 97.18%, Test Loss: 0.1159, Test Acc: 95.97%
# Epoch 127: Train Loss: 0.0704, Train Acc: 97.26%, Test Loss: 0.1146, Test Acc: 95.97%
# Epoch 128: Train Loss: 0.0698, Train Acc: 97.24%, Test Loss: 0.1145, Test Acc: 96.07%
# Epoch 129: Train Loss: 0.0709, Train Acc: 97.21%, Test Loss: 0.1139, Test Acc: 96.09%
# Epoch 130: Train Loss: 0.0698, Train Acc: 97.26%, Test Loss: 0.1168, Test Acc: 95.97%
# Epoch 131: Train Loss: 0.0706, Train Acc: 97.23%, Test Loss: 0.1152, Test Acc: 96.06%
# Epoch 132: Train Loss: 0.0692, Train Acc: 97.25%, Test Loss: 0.1172, Test Acc: 95.97%
# Epoch 133: Train Loss: 0.0698, Train Acc: 97.25%, Test Loss: 0.1204, Test Acc: 95.89%
# Epoch 134: Train Loss: 0.0692, Train Acc: 97.28%, Test Loss: 0.1223, Test Acc: 95.87%
# Epoch 135: Train Loss: 0.0690, Train Acc: 97.29%, Test Loss: 0.1230, Test Acc: 95.77%
# Epoch 136: Train Loss: 0.0693, Train Acc: 97.31%, Test Loss: 0.1190, Test Acc: 95.99%
# Epoch 137: Train Loss: 0.0685, Train Acc: 97.32%, Test Loss: 0.1189, Test Acc: 96.08%
# Epoch 138: Train Loss: 0.0685, Train Acc: 97.29%, Test Loss: 0.1175, Test Acc: 95.97%
# Epoch 139: Train Loss: 0.0684, Train Acc: 97.33%, Test Loss: 0.1187, Test Acc: 95.99%
# Epoch 140: Train Loss: 0.0680, Train Acc: 97.29%, Test Loss: 0.1201, Test Acc: 95.96%
# Epoch 141: Train Loss: 0.0681, Train Acc: 97.35%, Test Loss: 0.1194, Test Acc: 96.00%
# Epoch 142: Train Loss: 0.0681, Train Acc: 97.32%, Test Loss: 0.1222, Test Acc: 95.93%
# Epoch 143: Train Loss: 0.0682, Train Acc: 97.34%, Test Loss: 0.1237, Test Acc: 96.01%
# Epoch 144: Train Loss: 0.0672, Train Acc: 97.36%, Test Loss: 0.1206, Test Acc: 96.04%
# Epoch 145: Train Loss: 0.0679, Train Acc: 97.35%, Test Loss: 0.1198, Test Acc: 95.98%
# Epoch 146: Train Loss: 0.0674, Train Acc: 97.35%, Test Loss: 0.1225, Test Acc: 96.09%
# Epoch 147: Train Loss: 0.0674, Train Acc: 97.34%, Test Loss: 0.1154, Test Acc: 96.01%
# Epoch 148: Train Loss: 0.0671, Train Acc: 97.33%, Test Loss: 0.1194, Test Acc: 96.05%
# Epoch 149: Train Loss: 0.0673, Train Acc: 97.36%, Test Loss: 0.1171, Test Acc: 96.02%
# Epoch 150: Train Loss: 0.0667, Train Acc: 97.37%, Test Loss: 0.1174, Test Acc: 96.07%
# Epoch 151: Train Loss: 0.0667, Train Acc: 97.37%, Test Loss: 0.1206, Test Acc: 95.98%
# Epoch 152: Train Loss: 0.0676, Train Acc: 97.37%, Test Loss: 0.1196, Test Acc: 96.03%
# Epoch 153: Train Loss: 0.0665, Train Acc: 97.36%, Test Loss: 0.1253, Test Acc: 95.96%
# Epoch 154: Train Loss: 0.0671, Train Acc: 97.38%, Test Loss: 0.1201, Test Acc: 95.98%
# Epoch 155: Train Loss: 0.0659, Train Acc: 97.41%, Test Loss: 0.1192, Test Acc: 96.05%
# Epoch 156: Train Loss: 0.0658, Train Acc: 97.40%, Test Loss: 0.1215, Test Acc: 96.03%
# Epoch 157: Train Loss: 0.0663, Train Acc: 97.39%, Test Loss: 0.1255, Test Acc: 95.98%
# Epoch 158: Train Loss: 0.0667, Train Acc: 97.38%, Test Loss: 0.1225, Test Acc: 95.98%
# Epoch 159: Train Loss: 0.0653, Train Acc: 97.41%, Test Loss: 0.1254, Test Acc: 95.99%
# Epoch 160: Train Loss: 0.0654, Train Acc: 97.38%, Test Loss: 0.1233, Test Acc: 96.01%
# Epoch 161: Train Loss: 0.0651, Train Acc: 97.44%, Test Loss: 0.1224, Test Acc: 96.02%
# Epoch 162: Train Loss: 0.0653, Train Acc: 97.40%, Test Loss: 0.1207, Test Acc: 96.06%
# Epoch 163: Train Loss: 0.0649, Train Acc: 97.42%, Test Loss: 0.1260, Test Acc: 96.00%
# Epoch 164: Train Loss: 0.0645, Train Acc: 97.46%, Test Loss: 0.1230, Test Acc: 96.04%
# Epoch 165: Train Loss: 0.0648, Train Acc: 97.47%, Test Loss: 0.1214, Test Acc: 96.09%
# Epoch 166: Train Loss: 0.0643, Train Acc: 97.47%, Test Loss: 0.1226, Test Acc: 96.03%
# Epoch 167: Train Loss: 0.0649, Train Acc: 97.41%, Test Loss: 0.1181, Test Acc: 96.10%
# Epoch 168: Train Loss: 0.0643, Train Acc: 97.50%, Test Loss: 0.1213, Test Acc: 96.11%
# Epoch 169: Train Loss: 0.0640, Train Acc: 97.52%, Test Loss: 0.1221, Test Acc: 96.09%
# Epoch 170: Train Loss: 0.0643, Train Acc: 97.49%, Test Loss: 0.1252, Test Acc: 96.04%
# Epoch 171: Train Loss: 0.0644, Train Acc: 97.45%, Test Loss: 0.1230, Test Acc: 96.16%
# Epoch 172: Train Loss: 0.0643, Train Acc: 97.48%, Test Loss: 0.1268, Test Acc: 96.05%
# Epoch 173: Train Loss: 0.0637, Train Acc: 97.46%, Test Loss: 0.1197, Test Acc: 96.17%
# Epoch 174: Train Loss: 0.0642, Train Acc: 97.46%, Test Loss: 0.1166, Test Acc: 96.19%
# Epoch 175: Train Loss: 0.0632, Train Acc: 97.51%, Test Loss: 0.1239, Test Acc: 96.10%
# Epoch 176: Train Loss: 0.0639, Train Acc: 97.52%, Test Loss: 0.1206, Test Acc: 96.21%
# Epoch 177: Train Loss: 0.0636, Train Acc: 97.52%, Test Loss: 0.1206, Test Acc: 96.16%
# Epoch 178: Train Loss: 0.0623, Train Acc: 97.53%, Test Loss: 0.1236, Test Acc: 96.14%
# Epoch 179: Train Loss: 0.0637, Train Acc: 97.49%, Test Loss: 0.1257, Test Acc: 96.16%
# Epoch 180: Train Loss: 0.0636, Train Acc: 97.51%, Test Loss: 0.1175, Test Acc: 96.28%
# Epoch 181: Train Loss: 0.0627, Train Acc: 97.52%, Test Loss: 0.1249, Test Acc: 96.14%
# Epoch 182: Train Loss: 0.0636, Train Acc: 97.53%, Test Loss: 0.1188, Test Acc: 96.31%
# Epoch 183: Train Loss: 0.0627, Train Acc: 97.52%, Test Loss: 0.1221, Test Acc: 96.29%
# Epoch 184: Train Loss: 0.0624, Train Acc: 97.52%, Test Loss: 0.1205, Test Acc: 96.27%
# Epoch 185: Train Loss: 0.0626, Train Acc: 97.54%, Test Loss: 0.1212, Test Acc: 96.28%
# Epoch 186: Train Loss: 0.0622, Train Acc: 97.54%, Test Loss: 0.1243, Test Acc: 96.11%
# Epoch 187: Train Loss: 0.0627, Train Acc: 97.54%, Test Loss: 0.1212, Test Acc: 96.19%
# Epoch 188: Train Loss: 0.0626, Train Acc: 97.55%, Test Loss: 0.1255, Test Acc: 96.14%
# Epoch 189: Train Loss: 0.0619, Train Acc: 97.55%, Test Loss: 0.1183, Test Acc: 96.28%
# Epoch 190: Train Loss: 0.0618, Train Acc: 97.58%, Test Loss: 0.1213, Test Acc: 96.20%
# Epoch 191: Train Loss: 0.0619, Train Acc: 97.55%, Test Loss: 0.1251, Test Acc: 96.23%
# Epoch 192: Train Loss: 0.0618, Train Acc: 97.57%, Test Loss: 0.1254, Test Acc: 96.20%
# Epoch 193: Train Loss: 0.0618, Train Acc: 97.52%, Test Loss: 0.1260, Test Acc: 96.21%
# Epoch 194: Train Loss: 0.0623, Train Acc: 97.56%, Test Loss: 0.1221, Test Acc: 96.25%
# Epoch 195: Train Loss: 0.0614, Train Acc: 97.58%, Test Loss: 0.1232, Test Acc: 96.18%
# Epoch 196: Train Loss: 0.0606, Train Acc: 97.58%, Test Loss: 0.1225, Test Acc: 96.21%
# Epoch 197: Train Loss: 0.0616, Train Acc: 97.57%, Test Loss: 0.1218, Test Acc: 96.17%
# Epoch 198: Train Loss: 0.0613, Train Acc: 97.54%, Test Loss: 0.1258, Test Acc: 96.15%
# Epoch 199: Train Loss: 0.0613, Train Acc: 97.62%, Test Loss: 0.1228, Test Acc: 96.21%
# Epoch 200: Train Loss: 0.0611, Train Acc: 97.56%, Test Loss: 0.1267, Test Acc: 96.21%
# Epoch 201: Train Loss: 0.0608, Train Acc: 97.60%, Test Loss: 0.1293, Test Acc: 96.22%
# Epoch 202: Train Loss: 0.0608, Train Acc: 97.64%, Test Loss: 0.1274, Test Acc: 96.18%
# Epoch 203: Train Loss: 0.0607, Train Acc: 97.60%, Test Loss: 0.1281, Test Acc: 96.20%
# Epoch 204: Train Loss: 0.0614, Train Acc: 97.59%, Test Loss: 0.1314, Test Acc: 96.04%
# Epoch 205: Train Loss: 0.0606, Train Acc: 97.62%, Test Loss: 0.1258, Test Acc: 96.25%
# Epoch 206: Train Loss: 0.0604, Train Acc: 97.60%, Test Loss: 0.1308, Test Acc: 96.18%
# Epoch 207: Train Loss: 0.0603, Train Acc: 97.64%, Test Loss: 0.1422, Test Acc: 95.81%
# Epoch 208: Train Loss: 0.0608, Train Acc: 97.59%, Test Loss: 0.1252, Test Acc: 96.25%
# Epoch 209: Train Loss: 0.0604, Train Acc: 97.63%, Test Loss: 0.1300, Test Acc: 96.21%
# Epoch 210: Train Loss: 0.0601, Train Acc: 97.60%, Test Loss: 0.1374, Test Acc: 96.02%
# Epoch 211: Train Loss: 0.0601, Train Acc: 97.64%, Test Loss: 0.1328, Test Acc: 96.13%
# Epoch 212: Train Loss: 0.0599, Train Acc: 97.64%, Test Loss: 0.1338, Test Acc: 96.14%
# Epoch 213: Train Loss: 0.0593, Train Acc: 97.66%, Test Loss: 0.1337, Test Acc: 96.15%
# Epoch 214: Train Loss: 0.0594, Train Acc: 97.69%, Test Loss: 0.1312, Test Acc: 96.14%
# Epoch 215: Train Loss: 0.0591, Train Acc: 97.70%, Test Loss: 0.1284, Test Acc: 96.24%
# Epoch 216: Train Loss: 0.0595, Train Acc: 97.71%, Test Loss: 0.1364, Test Acc: 96.06%
# Epoch 217: Train Loss: 0.0597, Train Acc: 97.68%, Test Loss: 0.1506, Test Acc: 95.77%
# Epoch 218: Train Loss: 0.0597, Train Acc: 97.66%, Test Loss: 0.1316, Test Acc: 96.16%
# Epoch 219: Train Loss: 0.0594, Train Acc: 97.70%, Test Loss: 0.1358, Test Acc: 96.12%
# Epoch 220: Train Loss: 0.0593, Train Acc: 97.69%, Test Loss: 0.1410, Test Acc: 96.05%
# Epoch 221: Train Loss: 0.0588, Train Acc: 97.73%, Test Loss: 0.1391, Test Acc: 96.09%
# Epoch 222: Train Loss: 0.0591, Train Acc: 97.69%, Test Loss: 0.1337, Test Acc: 96.06%
# Epoch 223: Train Loss: 0.0589, Train Acc: 97.70%, Test Loss: 0.1310, Test Acc: 96.22%
# Epoch 224: Train Loss: 0.0587, Train Acc: 97.70%, Test Loss: 0.1307, Test Acc: 96.15%
# Epoch 225: Train Loss: 0.0587, Train Acc: 97.71%, Test Loss: 0.1261, Test Acc: 96.29%
# Epoch 226: Train Loss: 0.0585, Train Acc: 97.73%, Test Loss: 0.1316, Test Acc: 96.25%
# Epoch 227: Train Loss: 0.0589, Train Acc: 97.67%, Test Loss: 0.1398, Test Acc: 96.06%
# Epoch 228: Train Loss: 0.0581, Train Acc: 97.71%, Test Loss: 0.1360, Test Acc: 96.03%
# Epoch 229: Train Loss: 0.0592, Train Acc: 97.69%, Test Loss: 0.1449, Test Acc: 96.02%
# Epoch 230: Train Loss: 0.0585, Train Acc: 97.68%, Test Loss: 0.1423, Test Acc: 96.06%
# Epoch 231: Train Loss: 0.0580, Train Acc: 97.73%, Test Loss: 0.1391, Test Acc: 96.09%
# Epoch 232: Train Loss: 0.0587, Train Acc: 97.72%, Test Loss: 0.1397, Test Acc: 96.10%
# Epoch 233: Train Loss: 0.0582, Train Acc: 97.72%, Test Loss: 0.1420, Test Acc: 96.10%
# Epoch 234: Train Loss: 0.0586, Train Acc: 97.71%, Test Loss: 0.1336, Test Acc: 96.19%
# Epoch 235: Train Loss: 0.0586, Train Acc: 97.75%, Test Loss: 0.1330, Test Acc: 96.25%
# Epoch 236: Train Loss: 0.0577, Train Acc: 97.71%, Test Loss: 0.1327, Test Acc: 96.30%
# Epoch 237: Train Loss: 0.0573, Train Acc: 97.74%, Test Loss: 0.1471, Test Acc: 96.04%
# Epoch 238: Train Loss: 0.0584, Train Acc: 97.70%, Test Loss: 0.1538, Test Acc: 95.81%
# Epoch 239: Train Loss: 0.0587, Train Acc: 97.69%, Test Loss: 0.1523, Test Acc: 95.97%
# Epoch 240: Train Loss: 0.0576, Train Acc: 97.74%, Test Loss: 0.1398, Test Acc: 96.18%
# Epoch 241: Train Loss: 0.0583, Train Acc: 97.71%, Test Loss: 0.1404, Test Acc: 96.20%
# Epoch 242: Train Loss: 0.0572, Train Acc: 97.73%, Test Loss: 0.1422, Test Acc: 96.08%
# Epoch 243: Train Loss: 0.0573, Train Acc: 97.71%, Test Loss: 0.1504, Test Acc: 95.94%
# Epoch 244: Train Loss: 0.0574, Train Acc: 97.76%, Test Loss: 0.1441, Test Acc: 96.09%
# Epoch 245: Train Loss: 0.0579, Train Acc: 97.72%, Test Loss: 0.1418, Test Acc: 96.04%
# Epoch 246: Train Loss: 0.0567, Train Acc: 97.75%, Test Loss: 0.1304, Test Acc: 96.29%
# Epoch 247: Train Loss: 0.0571, Train Acc: 97.75%, Test Loss: 0.1373, Test Acc: 96.24%
# Epoch 248: Train Loss: 0.0583, Train Acc: 97.72%, Test Loss: 0.1337, Test Acc: 96.28%
# Epoch 249: Train Loss: 0.0570, Train Acc: 97.71%, Test Loss: 0.1475, Test Acc: 96.00%
# Epoch 250: Train Loss: 0.0567, Train Acc: 97.80%, Test Loss: 0.1350, Test Acc: 96.33%
# Epoch 251: Train Loss: 0.0575, Train Acc: 97.73%, Test Loss: 0.1386, Test Acc: 96.19%
# Epoch 252: Train Loss: 0.0570, Train Acc: 97.73%, Test Loss: 0.1387, Test Acc: 96.21%
# Epoch 253: Train Loss: 0.0565, Train Acc: 97.76%, Test Loss: 0.1515, Test Acc: 95.98%
# Epoch 254: Train Loss: 0.0577, Train Acc: 97.71%, Test Loss: 0.1508, Test Acc: 95.86%
# Epoch 255: Train Loss: 0.0562, Train Acc: 97.79%, Test Loss: 0.1465, Test Acc: 96.11%
# Epoch 256: Train Loss: 0.0571, Train Acc: 97.76%, Test Loss: 0.1428, Test Acc: 96.15%
# Epoch 257: Train Loss: 0.0559, Train Acc: 97.77%, Test Loss: 0.1480, Test Acc: 96.00%
# Epoch 258: Train Loss: 0.0561, Train Acc: 97.75%, Test Loss: 0.1303, Test Acc: 96.24%
# Epoch 259: Train Loss: 0.0569, Train Acc: 97.74%, Test Loss: 0.1410, Test Acc: 96.19%
# Epoch 260: Train Loss: 0.0564, Train Acc: 97.76%, Test Loss: 0.1442, Test Acc: 96.13%
# Epoch 261: Train Loss: 0.0554, Train Acc: 97.79%, Test Loss: 0.1555, Test Acc: 95.87%
# Epoch 262: Train Loss: 0.0563, Train Acc: 97.75%, Test Loss: 0.1511, Test Acc: 96.00%
# Epoch 263: Train Loss: 0.0561, Train Acc: 97.75%, Test Loss: 0.1413, Test Acc: 96.17%
# Epoch 264: Train Loss: 0.0559, Train Acc: 97.76%, Test Loss: 0.1480, Test Acc: 96.11%
# Epoch 265: Train Loss: 0.0558, Train Acc: 97.80%, Test Loss: 0.1369, Test Acc: 96.30%
# Epoch 266: Train Loss: 0.0559, Train Acc: 97.76%, Test Loss: 0.1386, Test Acc: 96.21%
# Epoch 267: Train Loss: 0.0557, Train Acc: 97.81%, Test Loss: 0.1380, Test Acc: 96.28%
# Epoch 268: Train Loss: 0.0556, Train Acc: 97.80%, Test Loss: 0.1316, Test Acc: 96.31%
# Epoch 269: Train Loss: 0.0559, Train Acc: 97.80%, Test Loss: 0.1410, Test Acc: 96.18%
# Epoch 270: Train Loss: 0.0555, Train Acc: 97.80%, Test Loss: 0.1348, Test Acc: 96.30%
# Epoch 271: Train Loss: 0.0554, Train Acc: 97.80%, Test Loss: 0.1459, Test Acc: 96.09%
# Epoch 272: Train Loss: 0.0552, Train Acc: 97.83%, Test Loss: 0.1444, Test Acc: 96.04%
# Epoch 273: Train Loss: 0.0550, Train Acc: 97.80%, Test Loss: 0.1538, Test Acc: 96.00%
# Epoch 274: Train Loss: 0.0554, Train Acc: 97.78%, Test Loss: 0.1545, Test Acc: 96.16%
# Epoch 275: Train Loss: 0.0559, Train Acc: 97.80%, Test Loss: 0.1461, Test Acc: 96.16%
# Epoch 276: Train Loss: 0.0556, Train Acc: 97.82%, Test Loss: 0.1477, Test Acc: 96.20%
# Epoch 277: Train Loss: 0.0550, Train Acc: 97.84%, Test Loss: 0.1463, Test Acc: 96.08%
# Epoch 278: Train Loss: 0.0546, Train Acc: 97.82%, Test Loss: 0.1557, Test Acc: 96.04%
# Epoch 279: Train Loss: 0.0550, Train Acc: 97.82%, Test Loss: 0.1454, Test Acc: 96.18%
# Epoch 280: Train Loss: 0.0562, Train Acc: 97.80%, Test Loss: 0.1425, Test Acc: 96.24%
# Epoch 281: Train Loss: 0.0551, Train Acc: 97.85%, Test Loss: 0.1474, Test Acc: 96.10%
# Epoch 282: Train Loss: 0.0549, Train Acc: 97.84%, Test Loss: 0.1566, Test Acc: 96.05%
# Epoch 283: Train Loss: 0.0554, Train Acc: 97.77%, Test Loss: 0.1449, Test Acc: 96.20%
# Epoch 284: Train Loss: 0.0541, Train Acc: 97.84%, Test Loss: 0.1488, Test Acc: 96.14%
# Epoch 285: Train Loss: 0.0550, Train Acc: 97.82%, Test Loss: 0.1510, Test Acc: 96.11%
# Epoch 286: Train Loss: 0.0552, Train Acc: 97.82%, Test Loss: 0.1384, Test Acc: 96.30%
# Epoch 287: Train Loss: 0.0540, Train Acc: 97.83%, Test Loss: 0.1538, Test Acc: 95.92%
# Epoch 288: Train Loss: 0.0545, Train Acc: 97.80%, Test Loss: 0.1553, Test Acc: 95.99%
# Epoch 289: Train Loss: 0.0545, Train Acc: 97.82%, Test Loss: 0.1425, Test Acc: 96.22%
# Epoch 290: Train Loss: 0.0550, Train Acc: 97.81%, Test Loss: 0.1540, Test Acc: 96.02%
# Epoch 291: Train Loss: 0.0542, Train Acc: 97.82%, Test Loss: 0.1463, Test Acc: 96.19%
# Epoch 292: Train Loss: 0.0543, Train Acc: 97.82%, Test Loss: 0.1703, Test Acc: 95.83%
# Epoch 293: Train Loss: 0.0542, Train Acc: 97.79%, Test Loss: 0.1585, Test Acc: 96.07%
# Epoch 294: Train Loss: 0.0549, Train Acc: 97.79%, Test Loss: 0.1445, Test Acc: 96.22%
# Epoch 295: Train Loss: 0.0542, Train Acc: 97.89%, Test Loss: 0.1444, Test Acc: 96.15%
# Epoch 296: Train Loss: 0.0541, Train Acc: 97.86%, Test Loss: 0.1482, Test Acc: 96.11%
# Epoch 297: Train Loss: 0.0549, Train Acc: 97.83%, Test Loss: 0.1750, Test Acc: 95.82%
# Epoch 298: Train Loss: 0.0542, Train Acc: 97.85%, Test Loss: 0.1575, Test Acc: 95.97%
# Epoch 299: Train Loss: 0.0534, Train Acc: 97.85%, Test Loss: 0.1471, Test Acc: 96.12%
# Epoch 300: Train Loss: 0.0538, Train Acc: 97.88%, Test Loss: 0.1540, Test Acc: 96.04%
# Epoch 301: Train Loss: 0.0532, Train Acc: 97.89%, Test Loss: 0.1706, Test Acc: 95.80%
# Epoch 302: Train Loss: 0.0540, Train Acc: 97.86%, Test Loss: 0.1603, Test Acc: 95.98%
# Epoch 303: Train Loss: 0.0544, Train Acc: 97.88%, Test Loss: 0.1668, Test Acc: 95.90%
# Epoch 304: Train Loss: 0.0530, Train Acc: 97.88%, Test Loss: 0.1662, Test Acc: 95.80%
# Epoch 305: Train Loss: 0.0533, Train Acc: 97.85%, Test Loss: 0.1599, Test Acc: 96.02%
# Epoch 306: Train Loss: 0.0538, Train Acc: 97.86%, Test Loss: 0.1659, Test Acc: 95.92%
# Epoch 307: Train Loss: 0.0535, Train Acc: 97.87%, Test Loss: 0.1610, Test Acc: 95.96%
# Epoch 308: Train Loss: 0.0530, Train Acc: 97.88%, Test Loss: 0.1587, Test Acc: 95.87%
# Epoch 309: Train Loss: 0.0536, Train Acc: 97.91%, Test Loss: 0.1690, Test Acc: 95.84%
# Epoch 310: Train Loss: 0.0538, Train Acc: 97.85%, Test Loss: 0.1600, Test Acc: 96.06%
# Epoch 311: Train Loss: 0.0527, Train Acc: 97.91%, Test Loss: 0.1700, Test Acc: 95.84%
# Epoch 312: Train Loss: 0.0530, Train Acc: 97.90%, Test Loss: 0.1549, Test Acc: 96.07%
# Epoch 313: Train Loss: 0.0522, Train Acc: 97.95%, Test Loss: 0.1630, Test Acc: 95.87%
# Epoch 314: Train Loss: 0.0532, Train Acc: 97.89%, Test Loss: 0.1701, Test Acc: 96.00%
# Epoch 315: Train Loss: 0.0529, Train Acc: 97.91%, Test Loss: 0.1621, Test Acc: 96.03%
# Epoch 316: Train Loss: 0.0522, Train Acc: 97.96%, Test Loss: 0.1583, Test Acc: 96.02%
# Epoch 317: Train Loss: 0.0535, Train Acc: 97.87%, Test Loss: 0.1728, Test Acc: 95.70%
# Epoch 318: Train Loss: 0.0531, Train Acc: 97.93%, Test Loss: 0.1590, Test Acc: 96.01%
# Epoch 319: Train Loss: 0.0522, Train Acc: 97.97%, Test Loss: 0.1644, Test Acc: 96.00%
# Epoch 320: Train Loss: 0.0530, Train Acc: 97.91%, Test Loss: 0.1528, Test Acc: 96.11%
# Epoch 321: Train Loss: 0.0518, Train Acc: 97.95%, Test Loss: 0.1580, Test Acc: 95.93%
# Epoch 322: Train Loss: 0.0533, Train Acc: 97.87%, Test Loss: 0.1577, Test Acc: 96.22%
# Epoch 323: Train Loss: 0.0520, Train Acc: 97.97%, Test Loss: 0.1524, Test Acc: 96.16%
# Epoch 324: Train Loss: 0.0532, Train Acc: 97.91%, Test Loss: 0.1614, Test Acc: 95.92%
# Epoch 325: Train Loss: 0.0524, Train Acc: 97.93%, Test Loss: 0.1618, Test Acc: 96.01%
# Epoch 326: Train Loss: 0.0520, Train Acc: 97.95%, Test Loss: 0.1673, Test Acc: 95.88%
# Epoch 327: Train Loss: 0.0527, Train Acc: 97.90%, Test Loss: 0.1610, Test Acc: 96.09%
# Epoch 328: Train Loss: 0.0514, Train Acc: 98.02%, Test Loss: 0.1657, Test Acc: 96.02%
# Epoch 329: Train Loss: 0.0522, Train Acc: 97.97%, Test Loss: 0.1707, Test Acc: 95.90%
# Epoch 330: Train Loss: 0.0527, Train Acc: 97.93%, Test Loss: 0.1626, Test Acc: 96.08%
# Epoch 331: Train Loss: 0.0517, Train Acc: 97.96%, Test Loss: 0.1635, Test Acc: 96.04%
# Epoch 332: Train Loss: 0.0514, Train Acc: 97.93%, Test Loss: 0.1692, Test Acc: 96.00%
# Epoch 333: Train Loss: 0.0514, Train Acc: 97.96%, Test Loss: 0.1593, Test Acc: 96.05%
# Epoch 334: Train Loss: 0.0516, Train Acc: 97.97%, Test Loss: 0.1669, Test Acc: 95.98%
# Epoch 335: Train Loss: 0.0513, Train Acc: 97.96%, Test Loss: 0.1709, Test Acc: 95.89%
# Epoch 336: Train Loss: 0.0514, Train Acc: 97.97%, Test Loss: 0.1579, Test Acc: 96.21%
# Epoch 337: Train Loss: 0.0528, Train Acc: 97.92%, Test Loss: 0.1588, Test Acc: 96.04%
# Epoch 338: Train Loss: 0.0511, Train Acc: 97.97%, Test Loss: 0.1607, Test Acc: 96.13%
# Epoch 339: Train Loss: 0.0514, Train Acc: 97.97%, Test Loss: 0.1606, Test Acc: 96.13%
# Epoch 340: Train Loss: 0.0510, Train Acc: 97.99%, Test Loss: 0.1714, Test Acc: 95.91%
# Epoch 341: Train Loss: 0.0521, Train Acc: 97.96%, Test Loss: 0.1711, Test Acc: 95.95%
# Epoch 342: Train Loss: 0.0522, Train Acc: 97.95%, Test Loss: 0.1596, Test Acc: 96.11%
# Epoch 343: Train Loss: 0.0512, Train Acc: 97.97%, Test Loss: 0.1618, Test Acc: 96.10%
# Epoch 344: Train Loss: 0.0516, Train Acc: 97.94%, Test Loss: 0.1566, Test Acc: 96.16%
# Epoch 345: Train Loss: 0.0509, Train Acc: 98.00%, Test Loss: 0.1732, Test Acc: 95.91%
# Epoch 346: Train Loss: 0.0501, Train Acc: 98.01%, Test Loss: 0.1707, Test Acc: 96.03%
# Epoch 347: Train Loss: 0.0517, Train Acc: 97.99%, Test Loss: 0.1711, Test Acc: 96.03%
# Epoch 348: Train Loss: 0.0508, Train Acc: 98.00%, Test Loss: 0.1601, Test Acc: 96.02%
# Epoch 349: Train Loss: 0.0519, Train Acc: 97.94%, Test Loss: 0.1516, Test Acc: 96.18%
# Epoch 350: Train Loss: 0.0509, Train Acc: 97.95%, Test Loss: 0.1563, Test Acc: 96.13%
# Epoch 351: Train Loss: 0.0517, Train Acc: 98.01%, Test Loss: 0.1613, Test Acc: 96.11%
# Epoch 352: Train Loss: 0.0504, Train Acc: 98.01%, Test Loss: 0.1545, Test Acc: 96.20%
# Epoch 353: Train Loss: 0.0517, Train Acc: 97.97%, Test Loss: 0.1616, Test Acc: 96.15%
# Epoch 354: Train Loss: 0.0510, Train Acc: 97.98%, Test Loss: 0.1715, Test Acc: 96.11%
# Epoch 355: Train Loss: 0.0513, Train Acc: 97.99%, Test Loss: 0.1561, Test Acc: 96.16%
# Epoch 356: Train Loss: 0.0505, Train Acc: 98.00%, Test Loss: 0.1661, Test Acc: 96.08%
# Epoch 357: Train Loss: 0.0505, Train Acc: 98.02%, Test Loss: 0.1633, Test Acc: 96.05%
# Epoch 358: Train Loss: 0.0504, Train Acc: 98.03%, Test Loss: 0.1684, Test Acc: 96.06%
# Epoch 359: Train Loss: 0.0495, Train Acc: 98.03%, Test Loss: 0.1641, Test Acc: 96.14%
# Epoch 360: Train Loss: 0.0507, Train Acc: 97.97%, Test Loss: 0.1629, Test Acc: 96.06%
# Epoch 361: Train Loss: 0.0511, Train Acc: 97.93%, Test Loss: 0.1547, Test Acc: 96.22%
# Epoch 362: Train Loss: 0.0500, Train Acc: 98.01%, Test Loss: 0.1667, Test Acc: 96.00%
# Epoch 363: Train Loss: 0.0505, Train Acc: 98.04%, Test Loss: 0.1612, Test Acc: 96.07%
# Epoch 364: Train Loss: 0.0502, Train Acc: 98.02%, Test Loss: 0.1637, Test Acc: 96.13%
# Epoch 365: Train Loss: 0.0506, Train Acc: 98.01%, Test Loss: 0.1619, Test Acc: 96.09%
# Epoch 366: Train Loss: 0.0509, Train Acc: 98.05%, Test Loss: 0.1577, Test Acc: 96.10%
# Epoch 367: Train Loss: 0.0496, Train Acc: 98.06%, Test Loss: 0.1552, Test Acc: 96.20%
# Epoch 368: Train Loss: 0.0492, Train Acc: 98.03%, Test Loss: 0.1642, Test Acc: 96.16%
# Epoch 369: Train Loss: 0.0507, Train Acc: 98.02%, Test Loss: 0.1643, Test Acc: 96.07%
# Epoch 370: Train Loss: 0.0499, Train Acc: 98.03%, Test Loss: 0.1618, Test Acc: 96.24%
# Epoch 371: Train Loss: 0.0495, Train Acc: 98.04%, Test Loss: 0.1602, Test Acc: 96.11%
# Epoch 372: Train Loss: 0.0497, Train Acc: 98.02%, Test Loss: 0.1576, Test Acc: 96.26%
# Epoch 373: Train Loss: 0.0494, Train Acc: 98.03%, Test Loss: 0.1635, Test Acc: 96.20%
# Epoch 374: Train Loss: 0.0498, Train Acc: 98.05%, Test Loss: 0.1627, Test Acc: 96.12%
# Epoch 375: Train Loss: 0.0489, Train Acc: 98.11%, Test Loss: 0.1676, Test Acc: 96.14%
# Epoch 376: Train Loss: 0.0504, Train Acc: 98.07%, Test Loss: 0.1555, Test Acc: 96.20%
# Epoch 377: Train Loss: 0.0487, Train Acc: 98.08%, Test Loss: 0.1560, Test Acc: 96.20%
# Epoch 378: Train Loss: 0.0496, Train Acc: 98.05%, Test Loss: 0.1562, Test Acc: 96.28%
# Epoch 379: Train Loss: 0.0495, Train Acc: 98.08%, Test Loss: 0.1631, Test Acc: 96.11%
# Epoch 380: Train Loss: 0.0486, Train Acc: 98.09%, Test Loss: 0.1565, Test Acc: 96.29%
# Epoch 381: Train Loss: 0.0498, Train Acc: 98.06%, Test Loss: 0.1491, Test Acc: 96.42%
# Epoch 382: Train Loss: 0.0488, Train Acc: 98.08%, Test Loss: 0.1552, Test Acc: 96.27%
# Epoch 383: Train Loss: 0.0493, Train Acc: 98.10%, Test Loss: 0.1568, Test Acc: 96.19%
# Epoch 384: Train Loss: 0.0494, Train Acc: 98.05%, Test Loss: 0.1536, Test Acc: 96.33%
# Epoch 385: Train Loss: 0.0488, Train Acc: 98.09%, Test Loss: 0.1627, Test Acc: 96.22%
# Epoch 386: Train Loss: 0.0497, Train Acc: 98.06%, Test Loss: 0.1625, Test Acc: 96.09%
# Epoch 387: Train Loss: 0.0490, Train Acc: 98.09%, Test Loss: 0.1620, Test Acc: 96.12%
# Epoch 388: Train Loss: 0.0477, Train Acc: 98.10%, Test Loss: 0.1642, Test Acc: 96.19%
# Epoch 389: Train Loss: 0.0485, Train Acc: 98.10%, Test Loss: 0.1515, Test Acc: 96.28%
# Epoch 390: Train Loss: 0.0491, Train Acc: 98.06%, Test Loss: 0.1547, Test Acc: 96.27%
# Epoch 391: Train Loss: 0.0486, Train Acc: 98.06%, Test Loss: 0.1593, Test Acc: 96.11%
# Epoch 392: Train Loss: 0.0485, Train Acc: 98.08%, Test Loss: 0.1508, Test Acc: 96.37%
# Epoch 393: Train Loss: 0.0496, Train Acc: 98.04%, Test Loss: 0.1532, Test Acc: 96.31%
# Epoch 394: Train Loss: 0.0482, Train Acc: 98.10%, Test Loss: 0.1617, Test Acc: 96.31%
# Epoch 395: Train Loss: 0.0485, Train Acc: 98.12%, Test Loss: 0.1613, Test Acc: 96.27%
# Epoch 396: Train Loss: 0.0484, Train Acc: 98.11%, Test Loss: 0.1603, Test Acc: 96.17%
# Epoch 397: Train Loss: 0.0484, Train Acc: 98.10%, Test Loss: 0.1530, Test Acc: 96.34%
# Epoch 398: Train Loss: 0.0484, Train Acc: 98.09%, Test Loss: 0.1536, Test Acc: 96.31%
# Epoch 399: Train Loss: 0.0486, Train Acc: 98.11%, Test Loss: 0.1583, Test Acc: 96.28%
# Epoch 400: Train Loss: 0.0489, Train Acc: 98.16%, Test Loss: 0.1571, Test Acc: 96.29%
# Epoch 401: Train Loss: 0.0489, Train Acc: 98.13%, Test Loss: 0.1612, Test Acc: 96.24%
# Epoch 402: Train Loss: 0.0489, Train Acc: 98.10%, Test Loss: 0.1577, Test Acc: 96.34%
# Epoch 403: Train Loss: 0.0484, Train Acc: 98.12%, Test Loss: 0.1494, Test Acc: 96.35%
# Epoch 404: Train Loss: 0.0491, Train Acc: 98.11%, Test Loss: 0.1568, Test Acc: 96.29%
# Epoch 405: Train Loss: 0.0481, Train Acc: 98.12%, Test Loss: 0.1500, Test Acc: 96.36%
# Epoch 406: Train Loss: 0.0479, Train Acc: 98.11%, Test Loss: 0.1599, Test Acc: 96.29%
# Epoch 407: Train Loss: 0.0494, Train Acc: 98.09%, Test Loss: 0.1516, Test Acc: 96.54%
# Epoch 408: Train Loss: 0.0485, Train Acc: 98.13%, Test Loss: 0.1521, Test Acc: 96.38%
# Epoch 409: Train Loss: 0.0483, Train Acc: 98.16%, Test Loss: 0.1634, Test Acc: 96.23%
# Epoch 410: Train Loss: 0.0494, Train Acc: 98.09%, Test Loss: 0.1549, Test Acc: 96.33%
# Epoch 411: Train Loss: 0.0482, Train Acc: 98.12%, Test Loss: 0.1510, Test Acc: 96.33%
# Epoch 412: Train Loss: 0.0472, Train Acc: 98.19%, Test Loss: 0.1530, Test Acc: 96.39%
# Epoch 413: Train Loss: 0.0478, Train Acc: 98.13%, Test Loss: 0.1557, Test Acc: 96.28%
# Epoch 414: Train Loss: 0.0473, Train Acc: 98.18%, Test Loss: 0.1595, Test Acc: 96.25%
# Epoch 415: Train Loss: 0.0475, Train Acc: 98.17%, Test Loss: 0.1670, Test Acc: 96.24%
# Epoch 416: Train Loss: 0.0478, Train Acc: 98.11%, Test Loss: 0.1591, Test Acc: 96.26%
# Epoch 417: Train Loss: 0.0470, Train Acc: 98.17%, Test Loss: 0.1577, Test Acc: 96.36%
# Epoch 418: Train Loss: 0.0475, Train Acc: 98.16%, Test Loss: 0.1554, Test Acc: 96.43%
# Epoch 419: Train Loss: 0.0478, Train Acc: 98.13%, Test Loss: 0.1584, Test Acc: 96.34%
# Epoch 420: Train Loss: 0.0491, Train Acc: 98.10%, Test Loss: 0.1535, Test Acc: 96.41%
# Epoch 421: Train Loss: 0.0466, Train Acc: 98.15%, Test Loss: 0.1646, Test Acc: 96.31%
# Epoch 422: Train Loss: 0.0495, Train Acc: 98.11%, Test Loss: 0.1657, Test Acc: 96.22%
# Epoch 423: Train Loss: 0.0481, Train Acc: 98.14%, Test Loss: 0.1593, Test Acc: 96.36%
# Epoch 424: Train Loss: 0.0475, Train Acc: 98.15%, Test Loss: 0.1576, Test Acc: 96.40%
# Epoch 425: Train Loss: 0.0471, Train Acc: 98.15%, Test Loss: 0.1495, Test Acc: 96.46%
# Epoch 426: Train Loss: 0.0481, Train Acc: 98.11%, Test Loss: 0.1636, Test Acc: 96.26%
# Epoch 427: Train Loss: 0.0473, Train Acc: 98.16%, Test Loss: 0.1686, Test Acc: 96.11%
# Epoch 428: Train Loss: 0.0471, Train Acc: 98.15%, Test Loss: 0.1617, Test Acc: 96.19%
# Epoch 429: Train Loss: 0.0471, Train Acc: 98.15%, Test Loss: 0.1575, Test Acc: 96.36%
# Epoch 430: Train Loss: 0.0467, Train Acc: 98.22%, Test Loss: 0.1601, Test Acc: 96.30%
# Epoch 431: Train Loss: 0.0477, Train Acc: 98.12%, Test Loss: 0.1668, Test Acc: 96.22%
# Epoch 432: Train Loss: 0.0474, Train Acc: 98.13%, Test Loss: 0.1637, Test Acc: 96.26%
# Epoch 433: Train Loss: 0.0470, Train Acc: 98.17%, Test Loss: 0.1623, Test Acc: 96.28%
# Epoch 434: Train Loss: 0.0460, Train Acc: 98.24%, Test Loss: 0.1586, Test Acc: 96.30%
# Epoch 435: Train Loss: 0.0480, Train Acc: 98.17%, Test Loss: 0.1625, Test Acc: 96.29%
# Epoch 436: Train Loss: 0.0469, Train Acc: 98.19%, Test Loss: 0.1517, Test Acc: 96.42%
# Epoch 437: Train Loss: 0.0473, Train Acc: 98.18%, Test Loss: 0.1489, Test Acc: 96.45%
# Epoch 438: Train Loss: 0.0470, Train Acc: 98.17%, Test Loss: 0.1609, Test Acc: 96.31%
# Epoch 439: Train Loss: 0.0464, Train Acc: 98.21%, Test Loss: 0.1645, Test Acc: 96.34%
# Epoch 440: Train Loss: 0.0485, Train Acc: 98.14%, Test Loss: 0.1501, Test Acc: 96.28%
# Epoch 441: Train Loss: 0.0465, Train Acc: 98.18%, Test Loss: 0.1576, Test Acc: 96.25%
# Epoch 442: Train Loss: 0.0465, Train Acc: 98.22%, Test Loss: 0.1592, Test Acc: 96.34%
# Epoch 443: Train Loss: 0.0465, Train Acc: 98.14%, Test Loss: 0.1540, Test Acc: 96.35%
# Epoch 444: Train Loss: 0.0465, Train Acc: 98.18%, Test Loss: 0.1594, Test Acc: 96.37%
# Epoch 445: Train Loss: 0.0464, Train Acc: 98.22%, Test Loss: 0.1577, Test Acc: 96.32%
# Epoch 446: Train Loss: 0.0478, Train Acc: 98.18%, Test Loss: 0.1577, Test Acc: 96.36%
# Epoch 447: Train Loss: 0.0478, Train Acc: 98.14%, Test Loss: 0.1567, Test Acc: 96.44%
# Epoch 448: Train Loss: 0.0461, Train Acc: 98.21%, Test Loss: 0.1595, Test Acc: 96.35%
# Epoch 449: Train Loss: 0.0467, Train Acc: 98.17%, Test Loss: 0.1632, Test Acc: 96.31%
# Epoch 450: Train Loss: 0.0457, Train Acc: 98.21%, Test Loss: 0.1588, Test Acc: 96.28%
# Epoch 451: Train Loss: 0.0475, Train Acc: 98.19%, Test Loss: 0.1617, Test Acc: 96.26%
# Epoch 452: Train Loss: 0.0464, Train Acc: 98.22%, Test Loss: 0.1586, Test Acc: 96.28%
# Epoch 453: Train Loss: 0.0461, Train Acc: 98.24%, Test Loss: 0.1524, Test Acc: 96.39%
# Epoch 454: Train Loss: 0.0462, Train Acc: 98.21%, Test Loss: 0.1560, Test Acc: 96.32%
# Epoch 455: Train Loss: 0.0473, Train Acc: 98.17%, Test Loss: 0.1588, Test Acc: 96.25%
# Epoch 456: Train Loss: 0.0460, Train Acc: 98.23%, Test Loss: 0.1621, Test Acc: 96.36%
# Epoch 457: Train Loss: 0.0451, Train Acc: 98.26%, Test Loss: 0.1526, Test Acc: 96.46%
# Epoch 458: Train Loss: 0.0460, Train Acc: 98.23%, Test Loss: 0.1639, Test Acc: 96.27%
# Epoch 459: Train Loss: 0.0467, Train Acc: 98.18%, Test Loss: 0.1629, Test Acc: 96.30%
# Epoch 460: Train Loss: 0.0472, Train Acc: 98.18%, Test Loss: 0.1592, Test Acc: 96.40%
# Epoch 461: Train Loss: 0.0470, Train Acc: 98.14%, Test Loss: 0.1565, Test Acc: 96.44%
# Epoch 462: Train Loss: 0.0459, Train Acc: 98.23%, Test Loss: 0.1567, Test Acc: 96.36%
# Epoch 463: Train Loss: 0.0460, Train Acc: 98.23%, Test Loss: 0.1614, Test Acc: 96.31%
# Epoch 464: Train Loss: 0.0463, Train Acc: 98.21%, Test Loss: 0.1669, Test Acc: 96.30%
# Epoch 465: Train Loss: 0.0455, Train Acc: 98.23%, Test Loss: 0.1590, Test Acc: 96.36%
# Epoch 466: Train Loss: 0.0466, Train Acc: 98.22%, Test Loss: 0.1576, Test Acc: 96.37%
# Epoch 467: Train Loss: 0.0458, Train Acc: 98.23%, Test Loss: 0.1585, Test Acc: 96.42%
# Epoch 468: Train Loss: 0.0464, Train Acc: 98.22%, Test Loss: 0.1618, Test Acc: 96.30%
# Epoch 469: Train Loss: 0.0464, Train Acc: 98.20%, Test Loss: 0.1619, Test Acc: 96.41%
# Epoch 470: Train Loss: 0.0466, Train Acc: 98.21%, Test Loss: 0.1565, Test Acc: 96.38%
# Epoch 471: Train Loss: 0.0455, Train Acc: 98.23%, Test Loss: 0.1670, Test Acc: 96.21%
# Epoch 472: Train Loss: 0.0463, Train Acc: 98.17%, Test Loss: 0.1602, Test Acc: 96.39%
# Epoch 473: Train Loss: 0.0464, Train Acc: 98.25%, Test Loss: 0.1588, Test Acc: 96.28%
# Epoch 474: Train Loss: 0.0476, Train Acc: 98.20%, Test Loss: 0.1530, Test Acc: 96.26%
# Epoch 475: Train Loss: 0.0462, Train Acc: 98.20%, Test Loss: 0.1591, Test Acc: 96.35%
# Epoch 476: Train Loss: 0.0455, Train Acc: 98.22%, Test Loss: 0.1500, Test Acc: 96.48%
# Epoch 477: Train Loss: 0.0449, Train Acc: 98.30%, Test Loss: 0.1593, Test Acc: 96.33%
# Epoch 478: Train Loss: 0.0453, Train Acc: 98.22%, Test Loss: 0.1543, Test Acc: 96.40%
# Epoch 479: Train Loss: 0.0467, Train Acc: 98.21%, Test Loss: 0.1491, Test Acc: 96.42%
# Epoch 480: Train Loss: 0.0452, Train Acc: 98.26%, Test Loss: 0.1611, Test Acc: 96.31%
# Epoch 481: Train Loss: 0.0461, Train Acc: 98.25%, Test Loss: 0.1527, Test Acc: 96.37%
# Epoch 482: Train Loss: 0.0458, Train Acc: 98.23%, Test Loss: 0.1558, Test Acc: 96.30%
# Epoch 483: Train Loss: 0.0440, Train Acc: 98.30%, Test Loss: 0.1652, Test Acc: 96.31%
# Epoch 484: Train Loss: 0.0457, Train Acc: 98.26%, Test Loss: 0.1607, Test Acc: 96.41%
# Epoch 485: Train Loss: 0.0468, Train Acc: 98.24%, Test Loss: 0.1672, Test Acc: 96.27%
# Epoch 486: Train Loss: 0.0464, Train Acc: 98.21%, Test Loss: 0.1678, Test Acc: 96.27%
# Epoch 487: Train Loss: 0.0458, Train Acc: 98.22%, Test Loss: 0.1546, Test Acc: 96.44%
# Epoch 488: Train Loss: 0.0459, Train Acc: 98.24%, Test Loss: 0.1599, Test Acc: 96.34%
# Epoch 489: Train Loss: 0.0468, Train Acc: 98.23%, Test Loss: 0.1629, Test Acc: 96.34%
# Epoch 490: Train Loss: 0.0455, Train Acc: 98.22%, Test Loss: 0.1666, Test Acc: 96.31%
# Epoch 491: Train Loss: 0.0451, Train Acc: 98.29%, Test Loss: 0.1761, Test Acc: 96.32%
# Epoch 492: Train Loss: 0.0457, Train Acc: 98.21%, Test Loss: 0.1646, Test Acc: 96.29%
# Epoch 493: Train Loss: 0.0457, Train Acc: 98.27%, Test Loss: 0.1538, Test Acc: 96.38%
# Epoch 494: Train Loss: 0.0445, Train Acc: 98.29%, Test Loss: 0.1662, Test Acc: 96.21%
# Epoch 495: Train Loss: 0.0452, Train Acc: 98.21%, Test Loss: 0.1551, Test Acc: 96.40%
# Epoch 496: Train Loss: 0.0453, Train Acc: 98.27%, Test Loss: 0.1739, Test Acc: 96.22%
# Epoch 497: Train Loss: 0.0451, Train Acc: 98.21%, Test Loss: 0.1609, Test Acc: 96.39%
# Epoch 498: Train Loss: 0.0449, Train Acc: 98.27%, Test Loss: 0.1686, Test Acc: 96.27%
# Epoch 499: Train Loss: 0.0450, Train Acc: 98.24%, Test Loss: 0.1653, Test Acc: 96.33%
# Epoch 500: Train Loss: 0.0452, Train Acc: 98.31%, Test Loss: 0.1697, Test Acc: 96.23%

# %% [markdown]
# ## Test

# %%
# predict the score for each action
def predict_score(data, model=net):
    model.eval()
    if not torch.is_tensor(data):
        data = torch.tensor(data, dtype=torch.float32)
    output = model(data)
    # Softmax
    output = F.softmax(output, dim=1)
    print(output)

# %%
def predict(data, model=net):
    model.eval()
    with torch.no_grad():
        # if data is not torch tensor, convert it to torch tensor
        if not torch.is_tensor(data):
            data = torch.tensor(data, dtype=torch.float32)
        output = model(data)
        return output.argmax(dim=1, keepdim=True)

# %%
sample1 = [[0.99, 0.90, 0.80, 0.80, 0.95, 0.95, 0.90, 0.85, 0.0, 0.0, 0.0, 0.0]]
sample2 = [[0.99, 0.90, 0.80, 0.80, 0.95, 0.95, 0.90, 0.85, 0.0, 0.0, 0.6, 0.7]]

# %%
predict(sample1)
# Out:
# tensor([[0]])

# %%
predict(sample2)
# Out:
# tensor([[5]])

# %%
predict_score(sample1)
predict_score(sample2)
# Out:
# tensor([[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.5359e-25]],
#        grad_fn=<SoftmaxBackward0>)
# tensor([[3.7056e-28, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]],
#        grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# # Multi Moddal training

# %% [markdown]
# ### Dataset

# %%
import torch
from torch.utils.data import Dataset, DataLoader

import pandas as pd

# %%
class MMDataset(Dataset):
    def __init__(self, csv_path, train=True):
        self.data = pd.read_csv(csv_path)
        # Drop the row which has 0 for the last -2, -3 columns
        # self.data = self.data.drop(self.data[(self.data.iloc[:, -2] == 0) & (self.data.iloc[:, -3] == 0)].index)

        if train:
            self.data = self.data.sample(frac=0.8, random_state=42)
        else:
            self.data = self.data.drop(self.data.sample(frac=0.8, random_state=42).index)

        self.data = self.transform(self.data)
        self.input1 = self.data[:, :-3]
        self.input2 = self.data[:, -3:-1]
        self.label = self.data[:, -1]
        # Long tensor for cross entropy loss
        self.label = torch.tensor(self.label, dtype=torch.long)

    def transform(self, data):
        return torch.tensor(data.values, dtype=torch.float32)

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.input1[idx], self.input2[idx], self.label[idx]

# %%
train_dataset = MMDataset('data.csv', train=True)
test_dataset = MMDataset('data.csv', train=False)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# /var/folders/gl/n3l9mrsx1jz4xhb0rsxhj8980000gn/T/ipykernel_3520/563110245.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.label = torch.tensor(self.label, dtype=torch.long)
# /var/folders/gl/n3l9mrsx1jz4xhb0rsxhj8980000gn/T/ipykernel_3520/563110245.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.label = torch.tensor(self.label, dtype=torch.long)

# %%
for batch in train_dataloader:
    input1, input2, labels = batch
    print(input1.shape, input2.shape, labels.shape)
    print(f"input1: {input1}\ninput2: {input2}\nlabels: {labels}")
    break
# Out:
# torch.Size([32, 10]) torch.Size([32, 2]) torch.Size([32])
# input1: tensor([[0.4800, 0.1100, 0.1000, 0.5700, 0.8100, 0.2800, 0.1800, 0.9800, 0.6300,
#          0.1300],
#         [0.3400, 1.0000, 0.3200, 0.6500, 0.4300, 0.7700, 0.7200, 0.2400, 0.8400,
#          0.1700],
#         [0.8800, 0.7000, 0.6600, 0.1100, 0.4900, 0.2900, 0.6500, 0.5100, 0.4300,
#          0.5300],
#         [0.1600, 0.0000, 0.7000, 0.6500, 0.6400, 0.9700, 0.1800, 0.0400, 0.7300,
#          0.0100],
#         [0.8700, 0.3700, 0.4800, 0.3700, 0.0400, 0.0800, 0.1500, 0.3000, 0.1300,
#          0.1500],
#         [0.9700, 0.0200, 0.5200, 0.8900, 0.1300, 0.8300, 0.0600, 0.1200, 0.0900,
#          0.3600],
#         [0.2300, 0.0200, 0.0700, 0.4400, 0.2300, 0.4700, 0.7700, 0.6900, 0.6000,
#          0.3600],
#         [0.6900, 0.5900, 0.4700, 0.6900, 0.5300, 0.8000, 0.1300, 0.3900, 0.3700,
#          0.7600],
#         [0.8000, 0.2500, 0.4200, 0.2300, 0.6300, 0.5800, 0.3200, 0.1800, 0.9700,
#          0.5100],
#         [0.8100, 0.8100, 0.4200, 0.5900, 0.5600, 0.7400, 0.8600, 0.4900, 0.9300,
#          0.5600],
#         [0.4900, 0.3200, 0.5100, 0.1900, 0.4700, 0.6200, 0.1200, 0.1500, 0.0600,
#          0.1000],
#         [0.5500, 0.1300, 0.8000, 0.2000, 0.0700, 0.8500, 0.7900, 0.2800, 0.2200,
#          0.0900],
#         [0.9300, 0.7800, 0.1600, 0.0300, 0.4900, 0.2000, 0.6100, 0.0400, 0.8000,
#          0.0800],
#         [0.0500, 0.2000, 0.9900, 0.8600, 0.5900, 0.1800, 0.7100, 0.4300, 0.1300,
#          0.9300],
#         [0.1400, 0.3900, 0.7100, 0.5100, 0.7400, 0.9500, 0.7300, 0.1700, 0.5900,
#          0.8100],
#         [0.5200, 0.4600, 0.1600, 0.5500, 0.1500, 0.6900, 0.2300, 0.3700, 0.6100,
#          0.6400],
#         [0.1900, 0.7200, 0.6400, 0.4700, 0.6900, 0.8900, 0.3300, 0.6600, 0.6400,
#          0.7600],
#         [0.0100, 0.8500, 0.2000, 0.3300, 0.5500, 0.3800, 0.3600, 0.0100, 0.7800,
#          0.9000],
#         [0.3000, 0.1600, 0.1600, 0.1700, 0.6500, 0.3700, 0.3800, 0.4500, 0.4400,
#          0.3500],
#         [0.7200, 0.0500, 0.5700, 0.5600, 0.9600, 0.2000, 0.5200, 0.1000, 0.9600,
#          0.1200],
#         [0.9800, 0.7700, 0.9600, 0.0500, 0.4700, 0.7400, 0.1000, 0.4000, 0.7100,
#          0.9300],
#         [0.5900, 0.8500, 0.2100, 0.9900, 0.5400, 0.7400, 0.3800, 0.1200, 0.8600,
#          0.5400],
#         [0.3900, 0.0100, 0.6700, 0.6100, 0.7100, 0.2100, 0.3900, 0.5700, 0.0100,
#          0.4200],
#         [0.0600, 0.2000, 0.0100, 0.0900, 0.6700, 0.3700, 0.5800, 0.4100, 0.1500,
#          0.1900],
#         [0.7100, 0.1200, 0.4800, 0.2800, 0.8700, 0.4500, 0.1000, 0.3100, 0.1600,
#          0.2900],
#         [0.6700, 0.5000, 0.2400, 0.0500, 0.3700, 0.5800, 0.2700, 0.5200, 0.6900,
#          0.6400],
#         [0.0600, 0.0800, 0.8400, 0.7900, 0.7600, 0.9500, 0.4000, 0.6400, 0.8800,
#          0.2200],
#         [0.6300, 0.7300, 0.2100, 0.1300, 0.8500, 0.0200, 0.3300, 0.8600, 0.4700,
#          0.1400],
#         [0.4700, 0.4200, 0.2100, 0.5500, 0.9500, 0.5200, 0.8800, 0.4400, 0.7300,
#          0.7000],
#         [0.9100, 0.4900, 0.3100, 0.0200, 0.4900, 0.1100, 0.8700, 0.7100, 0.7400,
#          0.9300],
#         [0.3700, 0.6100, 0.3800, 0.2500, 0.8300, 0.0000, 0.3900, 0.2100, 0.8900,
#          0.9600],
#         [0.5300, 0.4700, 0.2100, 0.2600, 0.4600, 0.8300, 0.3300, 0.9000, 0.6800,
#          0.3000]])
# input2: tensor([[0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.4000, 0.0300],
#         [0.2900, 0.4400],
#         [0.0000, 0.0000],
#         [0.0000, 0.0000],
#         [0.0200, 0.1600],
#         [0.0400, 0.1400],
#         [0.2600, 0.0500],
#         [0.0000, 0.0000],
#         [0.4000, 0.1500],
#         [0.3100, 0.3600],
#         [0.0000, 0.0000],
#         [0.3300, 0.0000],
#         [0.0000, 0.0000],
#         [0.2500, 0.3200],
#         [0.4400, 0.4400],
#         [0.4700, 0.3800],
#         [0.0000, 0.0100],
#         [0.2200, 0.0300],
#         [0.2200, 0.2000],
#         [0.2200, 0.0300],
#         [0.0400, 0.0400],
#         [0.0700, 0.4700],
#         [0.0600, 0.1100],
#         [0.1500, 0.2100],
#         [0.0200, 0.2000],
#         [0.3500, 0.0500],
#         [0.0200, 0.0400],
#         [0.2800, 0.5000],
#         [0.2800, 0.2900],
#         [0.2500, 0.0200]])
# labels: tensor([0, 0, 5, 1, 0, 0, 1, 4, 4, 0, 5, 5, 0, 1, 0, 4, 0, 2, 2, 2, 4, 4, 1, 2,
#         5, 2, 1, 2, 1, 2, 2, 2])

# %% [markdown]
# ## Step1:
# Pod + Nodes(5) as inputs, Outputting the best action, Comparing with default scheduler label

# %%
import torch.nn as nn
import torch.nn.functional as F

class MultiModalNet(nn.Module):
    def __init__(self):
        super(MultiModalNet, self).__init__()
        self.fc1_2 = nn.Linear(2, 16)   # Pod quota (CPU, Memory)
        self.fc1_10 = nn.Linear(10, 16) # 5 Nodes status (CPU, Memory)
        self.fc2 = nn.Linear(32, 16)    # Concatenated vector
        self.fc3 = nn.Linear(16, 6)     # 6-sized vector

    def forward(self, x2, x10):
        x2 = F.relu(self.fc1_2(x2))
        x10 = F.relu(self.fc1_10(x10))  
        x = torch.cat((x2, x10), dim=1) 
        x = F.relu(self.fc2(x))  
        x = self.fc3(x)     
        # x = F.softmax(self.fc3(x), dim=1)
        # x = torch.argmax(x, dim=1)
        return x

net_1 = MultiModalNet()
print(net_1)
# Out:
# MultiModalNet(
#   (fc1_2): Linear(in_features=2, out_features=16, bias=True)
#   (fc1_10): Linear(in_features=10, out_features=16, bias=True)
#   (fc2): Linear(in_features=32, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=6, bias=True)
# )

# %%
# Training
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net_1.parameters(), lr=0.001)

# %%
def train(model, train_loader, criterion, optimizer):
    model.train()
    train_loss = 0
    correct = 0
    for data10, data2, target in train_loader:
        optimizer.zero_grad()
        output = model(data2, data10)
        # print(f"output: {output}")
        # print(f"target: {target}")
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data2.size(0)
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
    train_loss /= len(train_loader.dataset)
    accuracy = 100. * correct / len(train_loader.dataset)
    return train_loss, accuracy

# %%
def test(model, test_loader, criterion):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data10, data2, target in test_loader:
            output = model(data2, data10)
            test_loss += criterion(output, target).item() * data2.size(0)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, accuracy

# %%
epochs = 500
test_acc = 0
for epoch in range(1, epochs+1):
    train_loss, train_acc = train(net_1, train_dataloader, criterion, optimizer)
    test_loss, test_acc = test(net_1, test_dataloader, criterion)
    print(f'Epoch {epoch}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%')
    if test_acc > 95:
        break
# Out:
# Epoch 1: Train Loss: 0.9316, Train Acc: 65.41%, Test Loss: 0.7023, Test Acc: 74.40%
# Epoch 2: Train Loss: 0.6733, Train Acc: 74.72%, Test Loss: 0.6485, Test Acc: 75.63%
# Epoch 3: Train Loss: 0.6241, Train Acc: 76.11%, Test Loss: 0.6077, Test Acc: 76.96%
# Epoch 4: Train Loss: 0.5980, Train Acc: 76.99%, Test Loss: 0.5921, Test Acc: 77.36%
# Epoch 5: Train Loss: 0.5888, Train Acc: 77.22%, Test Loss: 0.5873, Test Acc: 77.52%
# Epoch 6: Train Loss: 0.5854, Train Acc: 77.32%, Test Loss: 0.5855, Test Acc: 77.47%
# Epoch 7: Train Loss: 0.5840, Train Acc: 77.30%, Test Loss: 0.5847, Test Acc: 77.51%
# Epoch 8: Train Loss: 0.5670, Train Acc: 77.92%, Test Loss: 0.5448, Test Acc: 79.12%
# Epoch 9: Train Loss: 0.5320, Train Acc: 79.27%, Test Loss: 0.5226, Test Acc: 80.08%
# Epoch 10: Train Loss: 0.5184, Train Acc: 79.75%, Test Loss: 0.5141, Test Acc: 80.19%
# Epoch 11: Train Loss: 0.5134, Train Acc: 79.96%, Test Loss: 0.5110, Test Acc: 80.24%
# Epoch 12: Train Loss: 0.5114, Train Acc: 80.03%, Test Loss: 0.5095, Test Acc: 80.28%
# Epoch 13: Train Loss: 0.5104, Train Acc: 80.08%, Test Loss: 0.5086, Test Acc: 80.33%
# Epoch 14: Train Loss: 0.5098, Train Acc: 80.09%, Test Loss: 0.5081, Test Acc: 80.33%
# Epoch 15: Train Loss: 0.5094, Train Acc: 80.11%, Test Loss: 0.5077, Test Acc: 80.36%
# Epoch 16: Train Loss: 0.5090, Train Acc: 80.11%, Test Loss: 0.5073, Test Acc: 80.37%
# Epoch 17: Train Loss: 0.5085, Train Acc: 80.11%, Test Loss: 0.5071, Test Acc: 80.47%
# Epoch 18: Train Loss: 0.5081, Train Acc: 80.12%, Test Loss: 0.5068, Test Acc: 80.44%
# Epoch 19: Train Loss: 0.5076, Train Acc: 80.14%, Test Loss: 0.5066, Test Acc: 80.47%
# Epoch 20: Train Loss: 0.5070, Train Acc: 80.17%, Test Loss: 0.5058, Test Acc: 80.46%
# Epoch 21: Train Loss: 0.5060, Train Acc: 80.17%, Test Loss: 0.5041, Test Acc: 80.49%
# Epoch 22: Train Loss: 0.5040, Train Acc: 80.20%, Test Loss: 0.5018, Test Acc: 80.52%
# Epoch 23: Train Loss: 0.5020, Train Acc: 80.19%, Test Loss: 0.5008, Test Acc: 80.47%
# Epoch 24: Train Loss: 0.5005, Train Acc: 80.21%, Test Loss: 0.5003, Test Acc: 80.49%
# Epoch 25: Train Loss: 0.4997, Train Acc: 80.27%, Test Loss: 0.5001, Test Acc: 80.46%
# Epoch 26: Train Loss: 0.4992, Train Acc: 80.26%, Test Loss: 0.4998, Test Acc: 80.46%
# Epoch 27: Train Loss: 0.4989, Train Acc: 80.24%, Test Loss: 0.4995, Test Acc: 80.45%
# Epoch 28: Train Loss: 0.4987, Train Acc: 80.24%, Test Loss: 0.4990, Test Acc: 80.44%
# Epoch 29: Train Loss: 0.4985, Train Acc: 80.24%, Test Loss: 0.4990, Test Acc: 80.43%
# Epoch 30: Train Loss: 0.4983, Train Acc: 80.24%, Test Loss: 0.4986, Test Acc: 80.42%
# Epoch 31: Train Loss: 0.4982, Train Acc: 80.24%, Test Loss: 0.4987, Test Acc: 80.44%
# Epoch 32: Train Loss: 0.4981, Train Acc: 80.25%, Test Loss: 0.4985, Test Acc: 80.43%
# Epoch 33: Train Loss: 0.4979, Train Acc: 80.25%, Test Loss: 0.4983, Test Acc: 80.46%
# Epoch 34: Train Loss: 0.4973, Train Acc: 80.29%, Test Loss: 0.4969, Test Acc: 80.58%
# Epoch 35: Train Loss: 0.4956, Train Acc: 80.36%, Test Loss: 0.4951, Test Acc: 80.56%
# Epoch 36: Train Loss: 0.4943, Train Acc: 80.38%, Test Loss: 0.4942, Test Acc: 80.58%
# Epoch 37: Train Loss: 0.4935, Train Acc: 80.38%, Test Loss: 0.4939, Test Acc: 80.61%
# Epoch 38: Train Loss: 0.4931, Train Acc: 80.38%, Test Loss: 0.4939, Test Acc: 80.62%
# Epoch 39: Train Loss: 0.4928, Train Acc: 80.36%, Test Loss: 0.4932, Test Acc: 80.60%
# Epoch 40: Train Loss: 0.4927, Train Acc: 80.38%, Test Loss: 0.4933, Test Acc: 80.63%
# Epoch 41: Train Loss: 0.4925, Train Acc: 80.37%, Test Loss: 0.4932, Test Acc: 80.62%
# Epoch 42: Train Loss: 0.4924, Train Acc: 80.36%, Test Loss: 0.4930, Test Acc: 80.65%
# Epoch 43: Train Loss: 0.4923, Train Acc: 80.38%, Test Loss: 0.4931, Test Acc: 80.64%
# Epoch 44: Train Loss: 0.4922, Train Acc: 80.37%, Test Loss: 0.4932, Test Acc: 80.66%
# Epoch 45: Train Loss: 0.4922, Train Acc: 80.38%, Test Loss: 0.4931, Test Acc: 80.66%
# Epoch 46: Train Loss: 0.4922, Train Acc: 80.37%, Test Loss: 0.4930, Test Acc: 80.64%
# Epoch 47: Train Loss: 0.4921, Train Acc: 80.38%, Test Loss: 0.4930, Test Acc: 80.65%
# Epoch 48: Train Loss: 0.4921, Train Acc: 80.38%, Test Loss: 0.4930, Test Acc: 80.65%
# Epoch 49: Train Loss: 0.4921, Train Acc: 80.38%, Test Loss: 0.4931, Test Acc: 80.66%
# Epoch 50: Train Loss: 0.4920, Train Acc: 80.36%, Test Loss: 0.4929, Test Acc: 80.68%
# Epoch 51: Train Loss: 0.4919, Train Acc: 80.36%, Test Loss: 0.4929, Test Acc: 80.67%
# Epoch 52: Train Loss: 0.4919, Train Acc: 80.37%, Test Loss: 0.4930, Test Acc: 80.65%
# Epoch 53: Train Loss: 0.4918, Train Acc: 80.38%, Test Loss: 0.4926, Test Acc: 80.63%
# Epoch 54: Train Loss: 0.4918, Train Acc: 80.37%, Test Loss: 0.4926, Test Acc: 80.64%
# Epoch 55: Train Loss: 0.4917, Train Acc: 80.36%, Test Loss: 0.4930, Test Acc: 80.64%
# Epoch 56: Train Loss: 0.4917, Train Acc: 80.36%, Test Loss: 0.4925, Test Acc: 80.65%
# Epoch 57: Train Loss: 0.4917, Train Acc: 80.35%, Test Loss: 0.4929, Test Acc: 80.64%
# Epoch 58: Train Loss: 0.4916, Train Acc: 80.38%, Test Loss: 0.4926, Test Acc: 80.65%
# Epoch 59: Train Loss: 0.4916, Train Acc: 80.36%, Test Loss: 0.4929, Test Acc: 80.63%
# Epoch 60: Train Loss: 0.4916, Train Acc: 80.37%, Test Loss: 0.4915, Test Acc: 80.68%
# Epoch 61: Train Loss: 0.4915, Train Acc: 80.36%, Test Loss: 0.4914, Test Acc: 80.68%
# Epoch 62: Train Loss: 0.4915, Train Acc: 80.37%, Test Loss: 0.4928, Test Acc: 80.63%
# Epoch 63: Train Loss: 0.4915, Train Acc: 80.38%, Test Loss: 0.4926, Test Acc: 80.62%
# Epoch 64: Train Loss: 0.4914, Train Acc: 80.38%, Test Loss: 0.4929, Test Acc: 80.62%
# Epoch 65: Train Loss: 0.4914, Train Acc: 80.38%, Test Loss: 0.4924, Test Acc: 80.65%
# Epoch 66: Train Loss: 0.4914, Train Acc: 80.37%, Test Loss: 0.4914, Test Acc: 80.68%
# Epoch 67: Train Loss: 0.4913, Train Acc: 80.38%, Test Loss: 0.4915, Test Acc: 80.65%
# Epoch 68: Train Loss: 0.4913, Train Acc: 80.39%, Test Loss: 0.4923, Test Acc: 80.63%
# Epoch 69: Train Loss: 0.4913, Train Acc: 80.38%, Test Loss: 0.4922, Test Acc: 80.63%
# Epoch 70: Train Loss: 0.4913, Train Acc: 80.39%, Test Loss: 0.4924, Test Acc: 80.62%
# Epoch 71: Train Loss: 0.4912, Train Acc: 80.39%, Test Loss: 0.4921, Test Acc: 80.61%
# Epoch 72: Train Loss: 0.4912, Train Acc: 80.39%, Test Loss: 0.4922, Test Acc: 80.62%
# Epoch 73: Train Loss: 0.4912, Train Acc: 80.39%, Test Loss: 0.4921, Test Acc: 80.60%
# Epoch 74: Train Loss: 0.4911, Train Acc: 80.39%, Test Loss: 0.4914, Test Acc: 80.62%
# Epoch 75: Train Loss: 0.4911, Train Acc: 80.39%, Test Loss: 0.4920, Test Acc: 80.62%
# Epoch 76: Train Loss: 0.4911, Train Acc: 80.40%, Test Loss: 0.4913, Test Acc: 80.61%
# Epoch 77: Train Loss: 0.4910, Train Acc: 80.41%, Test Loss: 0.4918, Test Acc: 80.62%
# Epoch 78: Train Loss: 0.4910, Train Acc: 80.40%, Test Loss: 0.4915, Test Acc: 80.62%
# Epoch 79: Train Loss: 0.4910, Train Acc: 80.42%, Test Loss: 0.4915, Test Acc: 80.63%
# Epoch 80: Train Loss: 0.4909, Train Acc: 80.41%, Test Loss: 0.4916, Test Acc: 80.61%
# Epoch 81: Train Loss: 0.4909, Train Acc: 80.42%, Test Loss: 0.4911, Test Acc: 80.62%
# Epoch 82: Train Loss: 0.4909, Train Acc: 80.42%, Test Loss: 0.4916, Test Acc: 80.60%
# Epoch 83: Train Loss: 0.4909, Train Acc: 80.42%, Test Loss: 0.4916, Test Acc: 80.59%
# Epoch 84: Train Loss: 0.4909, Train Acc: 80.41%, Test Loss: 0.4914, Test Acc: 80.63%
# Epoch 85: Train Loss: 0.4908, Train Acc: 80.42%, Test Loss: 0.4914, Test Acc: 80.60%
# Epoch 86: Train Loss: 0.4908, Train Acc: 80.43%, Test Loss: 0.4914, Test Acc: 80.60%
# Epoch 87: Train Loss: 0.4907, Train Acc: 80.43%, Test Loss: 0.4916, Test Acc: 80.59%
# Epoch 88: Train Loss: 0.4907, Train Acc: 80.43%, Test Loss: 0.4914, Test Acc: 80.62%
# Epoch 89: Train Loss: 0.4907, Train Acc: 80.43%, Test Loss: 0.4913, Test Acc: 80.60%
# Epoch 90: Train Loss: 0.4906, Train Acc: 80.43%, Test Loss: 0.4915, Test Acc: 80.61%
# Epoch 91: Train Loss: 0.4906, Train Acc: 80.43%, Test Loss: 0.4913, Test Acc: 80.59%
# Epoch 92: Train Loss: 0.4906, Train Acc: 80.42%, Test Loss: 0.4912, Test Acc: 80.61%
# Epoch 93: Train Loss: 0.4906, Train Acc: 80.43%, Test Loss: 0.4911, Test Acc: 80.61%
# Epoch 94: Train Loss: 0.4905, Train Acc: 80.44%, Test Loss: 0.4913, Test Acc: 80.57%
# Epoch 95: Train Loss: 0.4905, Train Acc: 80.44%, Test Loss: 0.4909, Test Acc: 80.60%
# Epoch 96: Train Loss: 0.4904, Train Acc: 80.45%, Test Loss: 0.4909, Test Acc: 80.59%
# Epoch 97: Train Loss: 0.4904, Train Acc: 80.44%, Test Loss: 0.4907, Test Acc: 80.61%
# Epoch 98: Train Loss: 0.4903, Train Acc: 80.42%, Test Loss: 0.4906, Test Acc: 80.58%
# Epoch 99: Train Loss: 0.4902, Train Acc: 80.42%, Test Loss: 0.4901, Test Acc: 80.61%
# Epoch 100: Train Loss: 0.4900, Train Acc: 80.40%, Test Loss: 0.4900, Test Acc: 80.59%
# Epoch 101: Train Loss: 0.4898, Train Acc: 80.41%, Test Loss: 0.4898, Test Acc: 80.61%
# Epoch 102: Train Loss: 0.4896, Train Acc: 80.41%, Test Loss: 0.4897, Test Acc: 80.61%
# Epoch 103: Train Loss: 0.4895, Train Acc: 80.41%, Test Loss: 0.4897, Test Acc: 80.62%
# Epoch 104: Train Loss: 0.4894, Train Acc: 80.41%, Test Loss: 0.4895, Test Acc: 80.62%
# Epoch 105: Train Loss: 0.4893, Train Acc: 80.41%, Test Loss: 0.4896, Test Acc: 80.60%
# Epoch 106: Train Loss: 0.4892, Train Acc: 80.41%, Test Loss: 0.4892, Test Acc: 80.60%
# Epoch 107: Train Loss: 0.4890, Train Acc: 80.41%, Test Loss: 0.4894, Test Acc: 80.56%
# Epoch 108: Train Loss: 0.4889, Train Acc: 80.42%, Test Loss: 0.4890, Test Acc: 80.55%
# Epoch 109: Train Loss: 0.4887, Train Acc: 80.43%, Test Loss: 0.4890, Test Acc: 80.56%
# Epoch 110: Train Loss: 0.4886, Train Acc: 80.43%, Test Loss: 0.4886, Test Acc: 80.55%
# Epoch 111: Train Loss: 0.4884, Train Acc: 80.38%, Test Loss: 0.4891, Test Acc: 80.55%
# Epoch 112: Train Loss: 0.4883, Train Acc: 80.41%, Test Loss: 0.4889, Test Acc: 80.56%
# Epoch 113: Train Loss: 0.4882, Train Acc: 80.40%, Test Loss: 0.4883, Test Acc: 80.60%
# Epoch 114: Train Loss: 0.4880, Train Acc: 80.42%, Test Loss: 0.4881, Test Acc: 80.60%
# Epoch 115: Train Loss: 0.4879, Train Acc: 80.42%, Test Loss: 0.4879, Test Acc: 80.61%
# Epoch 116: Train Loss: 0.4878, Train Acc: 80.41%, Test Loss: 0.4879, Test Acc: 80.66%
# Epoch 117: Train Loss: 0.4876, Train Acc: 80.40%, Test Loss: 0.4879, Test Acc: 80.66%
# Epoch 118: Train Loss: 0.4875, Train Acc: 80.41%, Test Loss: 0.4880, Test Acc: 80.60%
# Epoch 119: Train Loss: 0.4874, Train Acc: 80.42%, Test Loss: 0.4880, Test Acc: 80.62%
# Epoch 120: Train Loss: 0.4873, Train Acc: 80.41%, Test Loss: 0.4877, Test Acc: 80.62%
# Epoch 121: Train Loss: 0.4872, Train Acc: 80.42%, Test Loss: 0.4875, Test Acc: 80.62%
# Epoch 122: Train Loss: 0.4871, Train Acc: 80.42%, Test Loss: 0.4874, Test Acc: 80.61%
# Epoch 123: Train Loss: 0.4870, Train Acc: 80.43%, Test Loss: 0.4874, Test Acc: 80.62%
# Epoch 124: Train Loss: 0.4869, Train Acc: 80.42%, Test Loss: 0.4874, Test Acc: 80.63%
# Epoch 125: Train Loss: 0.4868, Train Acc: 80.42%, Test Loss: 0.4873, Test Acc: 80.62%
# Epoch 126: Train Loss: 0.4868, Train Acc: 80.44%, Test Loss: 0.4873, Test Acc: 80.64%
# Epoch 127: Train Loss: 0.4867, Train Acc: 80.45%, Test Loss: 0.4874, Test Acc: 80.60%
# Epoch 128: Train Loss: 0.4867, Train Acc: 80.45%, Test Loss: 0.4873, Test Acc: 80.60%
# Epoch 129: Train Loss: 0.4866, Train Acc: 80.46%, Test Loss: 0.4872, Test Acc: 80.63%
# Epoch 130: Train Loss: 0.4866, Train Acc: 80.46%, Test Loss: 0.4871, Test Acc: 80.62%
# Epoch 131: Train Loss: 0.4865, Train Acc: 80.46%, Test Loss: 0.4870, Test Acc: 80.63%
# Epoch 132: Train Loss: 0.4865, Train Acc: 80.45%, Test Loss: 0.4871, Test Acc: 80.62%
# Epoch 133: Train Loss: 0.4865, Train Acc: 80.47%, Test Loss: 0.4870, Test Acc: 80.63%
# Epoch 134: Train Loss: 0.4864, Train Acc: 80.46%, Test Loss: 0.4868, Test Acc: 80.68%
# Epoch 135: Train Loss: 0.4864, Train Acc: 80.48%, Test Loss: 0.4865, Test Acc: 80.70%
# Epoch 136: Train Loss: 0.4864, Train Acc: 80.47%, Test Loss: 0.4866, Test Acc: 80.69%
# Epoch 137: Train Loss: 0.4863, Train Acc: 80.45%, Test Loss: 0.4868, Test Acc: 80.69%
# Epoch 138: Train Loss: 0.4863, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.71%
# Epoch 139: Train Loss: 0.4863, Train Acc: 80.47%, Test Loss: 0.4864, Test Acc: 80.68%
# Epoch 140: Train Loss: 0.4863, Train Acc: 80.46%, Test Loss: 0.4868, Test Acc: 80.69%
# Epoch 141: Train Loss: 0.4862, Train Acc: 80.49%, Test Loss: 0.4868, Test Acc: 80.68%
# Epoch 142: Train Loss: 0.4862, Train Acc: 80.47%, Test Loss: 0.4867, Test Acc: 80.71%
# Epoch 143: Train Loss: 0.4862, Train Acc: 80.50%, Test Loss: 0.4865, Test Acc: 80.75%
# Epoch 144: Train Loss: 0.4862, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.73%
# Epoch 145: Train Loss: 0.4862, Train Acc: 80.47%, Test Loss: 0.4866, Test Acc: 80.73%
# Epoch 146: Train Loss: 0.4861, Train Acc: 80.49%, Test Loss: 0.4866, Test Acc: 80.73%
# Epoch 147: Train Loss: 0.4861, Train Acc: 80.49%, Test Loss: 0.4869, Test Acc: 80.68%
# Epoch 148: Train Loss: 0.4861, Train Acc: 80.50%, Test Loss: 0.4866, Test Acc: 80.72%
# Epoch 149: Train Loss: 0.4861, Train Acc: 80.49%, Test Loss: 0.4867, Test Acc: 80.72%
# Epoch 150: Train Loss: 0.4861, Train Acc: 80.49%, Test Loss: 0.4867, Test Acc: 80.75%
# Epoch 151: Train Loss: 0.4860, Train Acc: 80.49%, Test Loss: 0.4867, Test Acc: 80.76%
# Epoch 152: Train Loss: 0.4860, Train Acc: 80.50%, Test Loss: 0.4868, Test Acc: 80.69%
# Epoch 153: Train Loss: 0.4860, Train Acc: 80.47%, Test Loss: 0.4868, Test Acc: 80.68%
# Epoch 154: Train Loss: 0.4861, Train Acc: 80.47%, Test Loss: 0.4866, Test Acc: 80.75%
# Epoch 155: Train Loss: 0.4860, Train Acc: 80.48%, Test Loss: 0.4866, Test Acc: 80.76%
# Epoch 156: Train Loss: 0.4860, Train Acc: 80.47%, Test Loss: 0.4865, Test Acc: 80.73%
# Epoch 157: Train Loss: 0.4860, Train Acc: 80.46%, Test Loss: 0.4863, Test Acc: 80.72%
# Epoch 158: Train Loss: 0.4860, Train Acc: 80.48%, Test Loss: 0.4862, Test Acc: 80.74%
# Epoch 159: Train Loss: 0.4860, Train Acc: 80.48%, Test Loss: 0.4865, Test Acc: 80.73%
# Epoch 160: Train Loss: 0.4859, Train Acc: 80.48%, Test Loss: 0.4862, Test Acc: 80.74%
# Epoch 161: Train Loss: 0.4859, Train Acc: 80.48%, Test Loss: 0.4862, Test Acc: 80.73%
# Epoch 162: Train Loss: 0.4859, Train Acc: 80.48%, Test Loss: 0.4866, Test Acc: 80.74%
# Epoch 163: Train Loss: 0.4859, Train Acc: 80.48%, Test Loss: 0.4862, Test Acc: 80.75%
# Epoch 164: Train Loss: 0.4859, Train Acc: 80.49%, Test Loss: 0.4866, Test Acc: 80.75%
# Epoch 165: Train Loss: 0.4859, Train Acc: 80.49%, Test Loss: 0.4861, Test Acc: 80.73%
# Epoch 166: Train Loss: 0.4859, Train Acc: 80.48%, Test Loss: 0.4862, Test Acc: 80.75%
# Epoch 167: Train Loss: 0.4858, Train Acc: 80.50%, Test Loss: 0.4863, Test Acc: 80.74%
# Epoch 168: Train Loss: 0.4858, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.73%
# Epoch 169: Train Loss: 0.4858, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.73%
# Epoch 170: Train Loss: 0.4858, Train Acc: 80.48%, Test Loss: 0.4864, Test Acc: 80.72%
# Epoch 171: Train Loss: 0.4858, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.72%
# Epoch 172: Train Loss: 0.4857, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.70%
# Epoch 173: Train Loss: 0.4857, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.69%
# Epoch 174: Train Loss: 0.4857, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.70%
# Epoch 175: Train Loss: 0.4857, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.72%
# Epoch 176: Train Loss: 0.4857, Train Acc: 80.48%, Test Loss: 0.4862, Test Acc: 80.72%
# Epoch 177: Train Loss: 0.4857, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.73%
# Epoch 178: Train Loss: 0.4857, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.74%
# Epoch 179: Train Loss: 0.4856, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.73%
# Epoch 180: Train Loss: 0.4856, Train Acc: 80.50%, Test Loss: 0.4862, Test Acc: 80.71%
# Epoch 181: Train Loss: 0.4856, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.72%
# Epoch 182: Train Loss: 0.4856, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.72%
# Epoch 183: Train Loss: 0.4855, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.73%
# Epoch 184: Train Loss: 0.4855, Train Acc: 80.49%, Test Loss: 0.4863, Test Acc: 80.72%
# Epoch 185: Train Loss: 0.4855, Train Acc: 80.50%, Test Loss: 0.4861, Test Acc: 80.71%
# Epoch 186: Train Loss: 0.4855, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.71%
# Epoch 187: Train Loss: 0.4854, Train Acc: 80.51%, Test Loss: 0.4862, Test Acc: 80.71%
# Epoch 188: Train Loss: 0.4854, Train Acc: 80.48%, Test Loss: 0.4863, Test Acc: 80.69%
# Epoch 189: Train Loss: 0.4854, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.70%
# Epoch 190: Train Loss: 0.4854, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.70%
# Epoch 191: Train Loss: 0.4853, Train Acc: 80.49%, Test Loss: 0.4862, Test Acc: 80.66%
# Epoch 192: Train Loss: 0.4853, Train Acc: 80.50%, Test Loss: 0.4862, Test Acc: 80.65%
# Epoch 193: Train Loss: 0.4853, Train Acc: 80.51%, Test Loss: 0.4862, Test Acc: 80.67%
# Epoch 194: Train Loss: 0.4851, Train Acc: 80.50%, Test Loss: 0.4861, Test Acc: 80.65%
# Epoch 195: Train Loss: 0.4850, Train Acc: 80.51%, Test Loss: 0.4861, Test Acc: 80.62%
# Epoch 196: Train Loss: 0.4849, Train Acc: 80.49%, Test Loss: 0.4859, Test Acc: 80.64%
# Epoch 197: Train Loss: 0.4848, Train Acc: 80.50%, Test Loss: 0.4856, Test Acc: 80.67%
# Epoch 198: Train Loss: 0.4846, Train Acc: 80.53%, Test Loss: 0.4856, Test Acc: 80.71%
# Epoch 199: Train Loss: 0.4845, Train Acc: 80.50%, Test Loss: 0.4854, Test Acc: 80.70%
# Epoch 200: Train Loss: 0.4843, Train Acc: 80.52%, Test Loss: 0.4854, Test Acc: 80.72%
# Epoch 201: Train Loss: 0.4841, Train Acc: 80.55%, Test Loss: 0.4853, Test Acc: 80.69%
# Epoch 202: Train Loss: 0.4840, Train Acc: 80.57%, Test Loss: 0.4850, Test Acc: 80.68%
# Epoch 203: Train Loss: 0.4838, Train Acc: 80.57%, Test Loss: 0.4846, Test Acc: 80.68%
# Epoch 204: Train Loss: 0.4836, Train Acc: 80.56%, Test Loss: 0.4844, Test Acc: 80.68%
# Epoch 205: Train Loss: 0.4834, Train Acc: 80.55%, Test Loss: 0.4845, Test Acc: 80.67%
# Epoch 206: Train Loss: 0.4833, Train Acc: 80.58%, Test Loss: 0.4842, Test Acc: 80.68%
# Epoch 207: Train Loss: 0.4831, Train Acc: 80.56%, Test Loss: 0.4841, Test Acc: 80.70%
# Epoch 208: Train Loss: 0.4830, Train Acc: 80.57%, Test Loss: 0.4838, Test Acc: 80.70%
# Epoch 209: Train Loss: 0.4828, Train Acc: 80.55%, Test Loss: 0.4837, Test Acc: 80.71%
# Epoch 210: Train Loss: 0.4827, Train Acc: 80.56%, Test Loss: 0.4836, Test Acc: 80.76%
# Epoch 211: Train Loss: 0.4825, Train Acc: 80.59%, Test Loss: 0.4834, Test Acc: 80.82%
# Epoch 212: Train Loss: 0.4823, Train Acc: 80.59%, Test Loss: 0.4832, Test Acc: 80.82%
# Epoch 213: Train Loss: 0.4819, Train Acc: 80.59%, Test Loss: 0.4827, Test Acc: 80.84%
# Epoch 214: Train Loss: 0.4811, Train Acc: 80.62%, Test Loss: 0.4810, Test Acc: 80.87%
# Epoch 215: Train Loss: 0.4786, Train Acc: 80.69%, Test Loss: 0.4765, Test Acc: 81.12%
# Epoch 216: Train Loss: 0.4677, Train Acc: 81.16%, Test Loss: 0.4564, Test Acc: 81.96%
# Epoch 217: Train Loss: 0.4418, Train Acc: 82.24%, Test Loss: 0.4282, Test Acc: 83.09%
# Epoch 218: Train Loss: 0.4210, Train Acc: 83.12%, Test Loss: 0.4132, Test Acc: 83.54%
# Epoch 219: Train Loss: 0.4126, Train Acc: 83.48%, Test Loss: 0.4085, Test Acc: 83.73%
# Epoch 220: Train Loss: 0.4095, Train Acc: 83.65%, Test Loss: 0.4066, Test Acc: 83.84%
# Epoch 221: Train Loss: 0.4082, Train Acc: 83.73%, Test Loss: 0.4058, Test Acc: 83.86%
# Epoch 222: Train Loss: 0.4073, Train Acc: 83.74%, Test Loss: 0.4052, Test Acc: 83.85%
# Epoch 223: Train Loss: 0.4068, Train Acc: 83.76%, Test Loss: 0.4047, Test Acc: 83.82%
# Epoch 224: Train Loss: 0.4065, Train Acc: 83.76%, Test Loss: 0.4044, Test Acc: 83.77%
# Epoch 225: Train Loss: 0.4061, Train Acc: 83.78%, Test Loss: 0.4049, Test Acc: 83.80%
# Epoch 226: Train Loss: 0.4058, Train Acc: 83.80%, Test Loss: 0.4055, Test Acc: 83.78%
# Epoch 227: Train Loss: 0.4055, Train Acc: 83.82%, Test Loss: 0.4044, Test Acc: 83.85%
# Epoch 228: Train Loss: 0.4052, Train Acc: 83.83%, Test Loss: 0.4045, Test Acc: 83.88%
# Epoch 229: Train Loss: 0.4051, Train Acc: 83.83%, Test Loss: 0.4040, Test Acc: 83.95%
# Epoch 230: Train Loss: 0.4049, Train Acc: 83.86%, Test Loss: 0.4037, Test Acc: 83.93%
# Epoch 231: Train Loss: 0.4048, Train Acc: 83.87%, Test Loss: 0.4036, Test Acc: 83.93%
# Epoch 232: Train Loss: 0.4046, Train Acc: 83.85%, Test Loss: 0.4041, Test Acc: 83.88%
# Epoch 233: Train Loss: 0.4046, Train Acc: 83.90%, Test Loss: 0.4037, Test Acc: 83.94%
# Epoch 234: Train Loss: 0.4044, Train Acc: 83.90%, Test Loss: 0.4034, Test Acc: 83.93%
# Epoch 235: Train Loss: 0.4043, Train Acc: 83.90%, Test Loss: 0.4034, Test Acc: 83.93%
# Epoch 236: Train Loss: 0.4041, Train Acc: 83.89%, Test Loss: 0.4034, Test Acc: 83.97%
# Epoch 237: Train Loss: 0.4041, Train Acc: 83.91%, Test Loss: 0.4035, Test Acc: 83.99%
# Epoch 238: Train Loss: 0.4040, Train Acc: 83.93%, Test Loss: 0.4036, Test Acc: 83.98%
# Epoch 239: Train Loss: 0.4039, Train Acc: 83.92%, Test Loss: 0.4032, Test Acc: 83.98%
# Epoch 240: Train Loss: 0.4039, Train Acc: 83.93%, Test Loss: 0.4029, Test Acc: 83.97%
# Epoch 241: Train Loss: 0.4038, Train Acc: 83.92%, Test Loss: 0.4030, Test Acc: 83.96%
# Epoch 242: Train Loss: 0.4037, Train Acc: 83.93%, Test Loss: 0.4028, Test Acc: 83.99%
# Epoch 243: Train Loss: 0.4036, Train Acc: 83.94%, Test Loss: 0.4029, Test Acc: 83.97%
# Epoch 244: Train Loss: 0.4035, Train Acc: 83.92%, Test Loss: 0.4030, Test Acc: 84.00%
# Epoch 245: Train Loss: 0.4034, Train Acc: 83.93%, Test Loss: 0.4029, Test Acc: 83.99%
# Epoch 246: Train Loss: 0.4034, Train Acc: 83.94%, Test Loss: 0.4029, Test Acc: 84.01%
# Epoch 247: Train Loss: 0.4033, Train Acc: 83.94%, Test Loss: 0.4029, Test Acc: 84.01%
# Epoch 248: Train Loss: 0.4032, Train Acc: 83.92%, Test Loss: 0.4030, Test Acc: 84.02%
# Epoch 249: Train Loss: 0.4032, Train Acc: 83.94%, Test Loss: 0.4027, Test Acc: 84.01%
# Epoch 250: Train Loss: 0.4031, Train Acc: 83.93%, Test Loss: 0.4027, Test Acc: 84.03%
# Epoch 251: Train Loss: 0.4031, Train Acc: 83.95%, Test Loss: 0.4030, Test Acc: 84.04%
# Epoch 252: Train Loss: 0.4030, Train Acc: 83.95%, Test Loss: 0.4027, Test Acc: 84.03%
# Epoch 253: Train Loss: 0.4029, Train Acc: 83.98%, Test Loss: 0.4027, Test Acc: 84.03%
# Epoch 254: Train Loss: 0.4028, Train Acc: 83.97%, Test Loss: 0.4024, Test Acc: 84.06%
# Epoch 255: Train Loss: 0.4027, Train Acc: 83.98%, Test Loss: 0.4024, Test Acc: 84.07%
# Epoch 256: Train Loss: 0.4027, Train Acc: 83.98%, Test Loss: 0.4022, Test Acc: 84.08%
# Epoch 257: Train Loss: 0.4026, Train Acc: 83.98%, Test Loss: 0.4021, Test Acc: 84.07%
# Epoch 258: Train Loss: 0.4026, Train Acc: 83.99%, Test Loss: 0.4022, Test Acc: 84.07%
# Epoch 259: Train Loss: 0.4025, Train Acc: 84.01%, Test Loss: 0.4021, Test Acc: 84.06%
# Epoch 260: Train Loss: 0.4024, Train Acc: 84.01%, Test Loss: 0.4021, Test Acc: 84.05%
# Epoch 261: Train Loss: 0.4024, Train Acc: 84.01%, Test Loss: 0.4022, Test Acc: 84.07%
# Epoch 262: Train Loss: 0.4023, Train Acc: 84.01%, Test Loss: 0.4022, Test Acc: 84.05%
# Epoch 263: Train Loss: 0.4022, Train Acc: 84.01%, Test Loss: 0.4021, Test Acc: 84.04%
# Epoch 264: Train Loss: 0.4022, Train Acc: 84.03%, Test Loss: 0.4020, Test Acc: 84.07%
# Epoch 265: Train Loss: 0.4021, Train Acc: 84.03%, Test Loss: 0.4020, Test Acc: 84.06%
# Epoch 266: Train Loss: 0.4021, Train Acc: 84.03%, Test Loss: 0.4021, Test Acc: 84.05%
# Epoch 267: Train Loss: 0.4020, Train Acc: 84.05%, Test Loss: 0.4019, Test Acc: 84.07%
# Epoch 268: Train Loss: 0.4013, Train Acc: 84.04%, Test Loss: 0.4014, Test Acc: 84.04%
# Epoch 269: Train Loss: 0.4007, Train Acc: 84.02%, Test Loss: 0.4011, Test Acc: 83.99%
# Epoch 270: Train Loss: 0.4004, Train Acc: 84.01%, Test Loss: 0.4011, Test Acc: 84.00%
# Epoch 271: Train Loss: 0.4002, Train Acc: 84.00%, Test Loss: 0.4013, Test Acc: 83.99%
# Epoch 272: Train Loss: 0.4000, Train Acc: 84.00%, Test Loss: 0.4009, Test Acc: 84.02%
# Epoch 273: Train Loss: 0.3999, Train Acc: 84.00%, Test Loss: 0.4010, Test Acc: 84.03%
# Epoch 274: Train Loss: 0.3998, Train Acc: 83.99%, Test Loss: 0.4010, Test Acc: 84.02%
# Epoch 275: Train Loss: 0.3997, Train Acc: 83.98%, Test Loss: 0.4001, Test Acc: 84.05%
# Epoch 276: Train Loss: 0.3997, Train Acc: 83.97%, Test Loss: 0.4002, Test Acc: 84.06%
# Epoch 277: Train Loss: 0.3996, Train Acc: 83.98%, Test Loss: 0.4002, Test Acc: 84.07%
# Epoch 278: Train Loss: 0.3996, Train Acc: 83.98%, Test Loss: 0.4002, Test Acc: 84.03%
# Epoch 279: Train Loss: 0.3995, Train Acc: 83.98%, Test Loss: 0.3999, Test Acc: 84.07%
# Epoch 280: Train Loss: 0.3995, Train Acc: 83.97%, Test Loss: 0.3999, Test Acc: 84.08%
# Epoch 281: Train Loss: 0.3994, Train Acc: 83.99%, Test Loss: 0.4002, Test Acc: 84.07%
# Epoch 282: Train Loss: 0.3994, Train Acc: 83.97%, Test Loss: 0.4000, Test Acc: 84.06%
# Epoch 283: Train Loss: 0.3993, Train Acc: 84.00%, Test Loss: 0.4000, Test Acc: 84.06%
# Epoch 284: Train Loss: 0.3993, Train Acc: 84.00%, Test Loss: 0.3997, Test Acc: 84.08%
# Epoch 285: Train Loss: 0.3993, Train Acc: 84.00%, Test Loss: 0.3998, Test Acc: 84.07%
# Epoch 286: Train Loss: 0.3993, Train Acc: 83.99%, Test Loss: 0.3997, Test Acc: 84.07%
# Epoch 287: Train Loss: 0.3992, Train Acc: 84.00%, Test Loss: 0.3997, Test Acc: 84.06%
# Epoch 288: Train Loss: 0.3993, Train Acc: 84.00%, Test Loss: 0.3995, Test Acc: 84.08%
# Epoch 289: Train Loss: 0.3992, Train Acc: 84.00%, Test Loss: 0.3994, Test Acc: 84.08%
# Epoch 290: Train Loss: 0.3992, Train Acc: 84.00%, Test Loss: 0.3992, Test Acc: 84.10%
# Epoch 291: Train Loss: 0.3992, Train Acc: 84.00%, Test Loss: 0.3991, Test Acc: 84.09%
# Epoch 292: Train Loss: 0.3992, Train Acc: 84.01%, Test Loss: 0.3993, Test Acc: 84.09%
# Epoch 293: Train Loss: 0.3991, Train Acc: 83.99%, Test Loss: 0.3991, Test Acc: 84.15%
# Epoch 294: Train Loss: 0.3991, Train Acc: 84.00%, Test Loss: 0.3992, Test Acc: 84.13%
# Epoch 295: Train Loss: 0.3991, Train Acc: 84.00%, Test Loss: 0.3993, Test Acc: 84.10%
# Epoch 296: Train Loss: 0.3991, Train Acc: 84.00%, Test Loss: 0.3993, Test Acc: 84.08%
# Epoch 297: Train Loss: 0.3990, Train Acc: 84.01%, Test Loss: 0.3995, Test Acc: 84.12%
# Epoch 298: Train Loss: 0.3990, Train Acc: 84.01%, Test Loss: 0.3992, Test Acc: 84.11%
# Epoch 299: Train Loss: 0.3990, Train Acc: 84.02%, Test Loss: 0.3990, Test Acc: 84.09%
# Epoch 300: Train Loss: 0.3990, Train Acc: 84.02%, Test Loss: 0.3994, Test Acc: 84.06%
# Epoch 301: Train Loss: 0.3990, Train Acc: 84.02%, Test Loss: 0.3992, Test Acc: 84.10%
# Epoch 302: Train Loss: 0.3989, Train Acc: 84.03%, Test Loss: 0.3995, Test Acc: 84.07%
# Epoch 303: Train Loss: 0.3989, Train Acc: 84.02%, Test Loss: 0.3991, Test Acc: 84.06%
# Epoch 304: Train Loss: 0.3989, Train Acc: 84.02%, Test Loss: 0.3994, Test Acc: 84.03%
# Epoch 305: Train Loss: 0.3988, Train Acc: 84.01%, Test Loss: 0.3993, Test Acc: 84.03%
# Epoch 306: Train Loss: 0.3988, Train Acc: 84.00%, Test Loss: 0.3991, Test Acc: 84.04%
# Epoch 307: Train Loss: 0.3988, Train Acc: 84.02%, Test Loss: 0.3992, Test Acc: 84.02%
# Epoch 308: Train Loss: 0.3988, Train Acc: 84.02%, Test Loss: 0.3992, Test Acc: 84.04%
# Epoch 309: Train Loss: 0.3988, Train Acc: 84.02%, Test Loss: 0.3992, Test Acc: 84.03%
# Epoch 310: Train Loss: 0.3987, Train Acc: 84.02%, Test Loss: 0.3993, Test Acc: 84.00%
# Epoch 311: Train Loss: 0.3987, Train Acc: 84.02%, Test Loss: 0.3992, Test Acc: 84.07%
# Epoch 312: Train Loss: 0.3987, Train Acc: 84.02%, Test Loss: 0.3992, Test Acc: 84.05%
# Epoch 313: Train Loss: 0.3987, Train Acc: 84.00%, Test Loss: 0.3992, Test Acc: 84.06%
# Epoch 314: Train Loss: 0.3987, Train Acc: 84.01%, Test Loss: 0.3992, Test Acc: 84.04%
# Epoch 315: Train Loss: 0.3986, Train Acc: 84.00%, Test Loss: 0.3995, Test Acc: 84.07%
# Epoch 316: Train Loss: 0.3986, Train Acc: 84.01%, Test Loss: 0.3993, Test Acc: 84.07%
# Epoch 317: Train Loss: 0.3986, Train Acc: 84.01%, Test Loss: 0.3992, Test Acc: 84.06%
# Epoch 318: Train Loss: 0.3986, Train Acc: 84.00%, Test Loss: 0.3994, Test Acc: 84.07%
# Epoch 319: Train Loss: 0.3986, Train Acc: 84.00%, Test Loss: 0.3994, Test Acc: 84.08%
# Epoch 320: Train Loss: 0.3985, Train Acc: 84.00%, Test Loss: 0.3994, Test Acc: 84.07%
# Epoch 321: Train Loss: 0.3985, Train Acc: 84.00%, Test Loss: 0.3993, Test Acc: 84.07%
# Epoch 322: Train Loss: 0.3985, Train Acc: 84.01%, Test Loss: 0.3991, Test Acc: 84.10%
# Epoch 323: Train Loss: 0.3985, Train Acc: 84.01%, Test Loss: 0.3993, Test Acc: 84.09%
# Epoch 324: Train Loss: 0.3984, Train Acc: 83.99%, Test Loss: 0.3993, Test Acc: 84.09%
# Epoch 325: Train Loss: 0.3984, Train Acc: 83.98%, Test Loss: 0.3994, Test Acc: 84.08%
# Epoch 326: Train Loss: 0.3984, Train Acc: 84.00%, Test Loss: 0.3993, Test Acc: 84.12%
# Epoch 327: Train Loss: 0.3984, Train Acc: 84.01%, Test Loss: 0.3991, Test Acc: 84.10%
# Epoch 328: Train Loss: 0.3984, Train Acc: 83.99%, Test Loss: 0.3992, Test Acc: 84.13%

# %% [markdown]
# # RL algorithm

# %%
# A3C model
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class A3C(nn.Module):
    def __init__(self, input_size, output_size):
        super(A3C, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.actor = nn.Linear(64, output_size)
        self.critic = nn.Linear(64, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        policy = F.softmax(self.actor(x), dim=-1)
        value = self.critic(x)
        return policy, value
    
    def act(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0)
        policy, _ = self.forward(state)
        action = policy.multinomial(1)
        return action.item()
    
    def evaluate(self, state):
        policy, value = self.forward(state)
        return policy, value
    
    def get_action(self, state):
        policy, _ = self.forward(state)
        action = policy.max(1)[1].detach().numpy()[0]
        return action
    
    def get_value(self, state):
        _, value = self.forward(state)
        return value
    
    def get_policy(self, state):
        policy, _ = self.forward(state)
        return policy
    
    def get_entropy(self, state):
        policy, _ = self.forward(state)
        entropy = -(policy * torch.log(policy)).sum(1).mean()
        return entropy
    
    def get_log_prob(self, state, action):
        policy, _ = self.forward(state)
        action_prob = policy.gather(1, action)
        log_prob = torch.log(action_prob)
        return log_prob
    
    def get_loss(self, state, action, reward, next_state, done, gamma=0.99, beta=0.01):
        _, value = self.evaluate(state)
        _, next_value = self.evaluate(next_state)
        target = reward + gamma * next_value * (1 - done)
        delta = target - value
        policy, _ = self.forward(state)
        action_prob = policy.gather(1, action)
        log_prob = torch.log(action_prob)
        entropy = -(policy * torch.log(policy)).sum(1).mean()
        loss = -log_prob * delta.detach() + beta * entropy
        return loss.mean()

# %%
# A3C agent
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gym
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
import random

class A3CAgent:
    def __init__(self, env):
        self.env = env
        self.state_size = env.observation_space.shape[0]
        self.action_size = env.action_space.n
        self.model = A3C(self.state_size, self.action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        
    def train(self, max_episode_num=500):
        episode, episode_reward, done = 0, 0, False
        state = self.env.reset()
        while episode < max_episode_num:
            action = self.model.act(state)
            next_state, reward, done, _ = self.env.step(action)
            self.optimizer.zero_grad()
            loss = self.model.get_loss(state, action, reward, next_state, done)
            loss.backward()
            self.optimizer.step()
            state = next_state
            episode_reward += reward
            if done:
                print(f'Episode: {episode+1}, Episode Reward: {episode_reward:.2f}')
                episode += 1
                episode_reward = 0
                state = self.env.reset()
        self.env.close()
    
    def play(self):
        state = self.env.reset()
        done = False
        while not done:
            self.env.render()
            action = self.model.get_action(state)
            next_state, reward, done, _ = self.env.step(action)
            state = next_state
        self.env.close()
